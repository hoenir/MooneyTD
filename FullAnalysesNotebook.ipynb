# %% [markdown]
# # Analyses MooneyTD task in AQ trait (students) and ASD (adolescents)
#
# **Researchers: Sander Van de Cruys, Ines Van de Put (MA thesis student), Steven Vanmarcke (data collection), Johan Wagemans**
# ___
#
#
# Notes:
# * All errorbars are **95% CIs**
# * Mooney (pretest, exposure phase, posttest; "MooneyTD")
# * dependent vars: recognition acc and count (number of guesses irrespective of accurate recognition, could also give a measure of "top-down generative strength").
#
#
# * 1s target duration
# * 2s template duration
# * 750ms iti
#
#
# Mooney task based on:
#
# > Teufel, C., Subramaniam, N., Dobler, V., Perez, J., Finnemann, J., Mehta, P. R., … Fletcher, P. C. (2015). Shift toward prior knowledge confers a perceptual advantage in early psychosis and psychosis-prone healthy individuals. Proceedings of the National Academy of Sciences of the United States of America, 112(43), 13401–13406.
#
# *Study 1*:
#
# * About 300 subjects (students)
# * AQ traits measured
#
# *Study 2*:
#
# * 25 participants in each group (adolescents, matched on IQ and gender by Steven)
# * notes: 204/229 (acc lower than .2)

# %%
import numpy as np
import pandas as pd
import csv, json
from fuzzywuzzy import fuzz

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from __future__ import print_function
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.weightstats import ttest_ind
from bambi import Model, Family, Prior #Bayesian model building

# %pylab inline
sns.set(style="whitegrid")
sns.set_context("talk")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Load the IPython magic extension to use R within this notebook and import external R packages we'll use.

# %%
# %reload_ext rpy2.ipython
# %R -n library(lme4)

# %% [markdown]
# Define an R function to facilitate reporting of likelihood ratio test of nested LMEMs.

# %%
# %%R
# lr.test = function(m1, m2, name){
#     print(summary(m1))
#     print(summary(m2))
#     out = anova(m1, m2)
#     chi2 = out$Chisq[2]
#     dof = out$"Chi Df"[2]
#     p = out$"Pr(>Chisq)"[2]
#     test_str = "Likelihood ratio test for %s:\n  Chisq(%d) = %.2f; p = %.3g"
#     writeLines(sprintf(test_str, name, dof, chi2, p))
# }

# %% [markdown]
# Control saving figures globally with this function so it is easy to switch between file types and possibly other options.

# %%
def save_fig(fig, figname):
    fig.savefig("figs/%s.pdf" % figname, dpi=300)
    fig.savefig("figs/%s.png" % figname, dpi=300)
    fig.savefig("figs/%s.svg" % figname, dpi=300)

# %% [markdown]
# # Study 1: Correlating AQ with Mooney performance
#
# **!!! Don't run this again, import preprocessed data below, starting section 2.4 or 2.9 (merged, clean data) !!!**

# %% [markdown]
# ## Scoring AQ

# %%
#starting from raw google form data

df = pd.read_csv("AQ_Data/AQCOdec2015.csv")

labels = ["id","sex","age"]

items= [str(x+1) for x in range(50)]
labels=labels+items

df.columns = labels

# %%
#starting from clean data
df = pd.read_csv("AQ_Data/COdec2015AQ.csv")
df.head()

# %%
repsOptions= {"Definitely agree":1, "Slightly agree": 2, 
              "Slightly disagree":3, "Definitely disagree":4}


qLow= [1, 2, 4, 5, 6, 7, 9, 12, 13, 16, 18, 19, 20, 21, 22, 23, 26, 33, 35, 
       39, 41, 42, 43, 45, 46]

qHigh= [3, 8, 10, 11, 14, 15, 17, 24, 25, 27, 28, 29, 30, 31, 32, 34, 36, 
        37, 38, 40, 44, 47, 48, 49, 50]

# items for subscales: Baron-Cohen
socialskill = [1,11,13,15,22,36,44,45,47,48] 
attswitch = [2,4,10,16,25,32,34,37,43,46] 
attdetail = [5,6,9,12,19,23,28,29,30,49] 
comm = [7,17,18,26,27,31,33,35,38,39] 
imagination = [3,8,14,20,21,24,40,41,42,50]

""" In the first major trial using the test, 
the average score in the control group was 16.4. 
Eighty percent of those diagnosed with autism or 
a related disorder scored 32 or higher. 
The test is not a means for making a diagnosis, 
however, and many who score above 32 and even 
meet the diagnostic criteria for mild autism or 
Asperger’s report no difficulty functioning 
.in their everyday lives. from http://aspergerstest.net/interpreting-aq-test-results/"""

def scoreBC(row):
    """ score binary like original Baron-Cohen"""
    aqscore=0
    
    for i in qLow:
        if row[str(i)] <=2 :
            aqscore+=1
        
    for i in qHigh:
        if row[str(i)] > 2 :
            aqscore+=1
            
               
    return aqscore

def scoreLikert(row):
    """ score 4-point likert """
    likertscore=0
    
    for i in qLow:
        likertscore += 5-row[str(i)]
        
    for i in qHigh:
        likertscore += row[str(i)]
            
               
    return likertscore

def scoresubscale(row, sub):
    """ score on nonsocial items"""
    
    subscore=0
    
    for i in sub:
        if i in qLow:
            subscore += 5-row[str(i)]

        if i in qHigh:
            subscore += row[str(i)]

               
    return subscore

df['AQ'] = df.apply(scoreBC, axis=1)
df['AQlikert'] = df.apply(scoreLikert, axis=1)
df['AQattDetail'] = df.apply(scoresubscale, axis=1, args=([attdetail]))
df['AQsocialSkill'] = df.apply(scoresubscale, axis=1, args=([socialskill]))
df['AQattSwitch'] = df.apply(scoresubscale, axis=1, args=([attswitch]))
df['AQcomm'] = df.apply(scoresubscale, axis=1, args=([comm]))
df['AQimagination'] = df.apply(scoresubscale, axis=1, args=([imagination]))

# %%
df[['id','AQ']]
df.to_csv("AQ_Data/COdec2015AQ.csv")

df.head()

# %% [markdown]
# ## Preprocessing mooneyTD

# %%
with open('AQ_Data/mooneyTDCOdec2015.csv', 'Ur') as f:
    data = list(list(rec) for rec in csv.reader(f, delimiter='\t'))

expandata=[]

print len(data)
expandata.append(["id", "trialnb", "blocknb", "prepost", "stim", "response", "rt"])

#print data[1][2]


for i,row in enumerate(data):
    
    
    if i==0:
        continue
    else:
        trials=row[2].split('\n')
        
        for trial in trials:
            
            trial = trial.strip('[]')
            if trial=="": continue
            trial = trial.split(',')            
            expandata.append(trial)

print len(expandata)

with open("AQ_Data/datMooneyTD.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(expandata)

# %% [markdown]
# ## Correct responses with answer key

# %%
df = pd.read_csv("AQ_Data/datMooneyTD.csv")


def correct(df):


    rk = pd.read_csv("mooneyanswerkey.csv",delimiter='\t')
    acccol = []
    correctRespcol = []
        
    
    for rowNb, row in df.iterrows():


        answer = str(row['response'])
        acc=0
        

        if answer!='':
            answer=answer.lower()

            img= row['stim']

            img=img.split('http://www.tureluurs.be/onlineExp/mooneyTD/')
        
            img=img[1].strip('"')
            
            sols= rk.sol[rk['tt'] == img]
            sols=np.array(sols)[0].split(',')
            correctResp=sols

            for i in sols:
                i.strip()
                if fuzz.ratio(i,answer) > 70:
                    acc=1
                    break

        acccol.append(acc)
        correctRespcol.append(correctResp)

    df['acc'] = acccol
    df['correctResp'] = correctRespcol
    #print acccol
    return df    

df = correct(df)
df.head()
df.to_csv('AQ_Data/dataMooneyTDwithAcc.csv')

# %% [markdown]
# ## Preprocessing done

# %%
df= pd.read_csv('AQ_Data/dataMooneyTDwithAcc.csv')
df["blocknb"]=df.blocknb + 1 #block starts from 0 instead of 1
df.head()
# Out:
#    Unnamed: 0     id  trialnb  blocknb prepost  \
# 0           0  20524        0        1     pre
# 1           1  20524        1        1     pre
# 2           2  20524        2        1     pre
# 3           3  20524        3        1     pre
# 4           4  20524        4        1     pre
#
#                                                 stim  response    rt  \
# 0  http://www.tureluurs.be/onlineExp/mooneyTD/img...  krokodil  3308
# 1  http://www.tureluurs.be/onlineExp/mooneyTD/img...     leeuw  2715
# 2  http://www.tureluurs.be/onlineExp/mooneyTD/img...      mens  3286
# 3  http://www.tureluurs.be/onlineExp/mooneyTD/img...       aap  3245
# 4  http://www.tureluurs.be/onlineExp/mooneyTD/img...      neus  2828
#
#    Unnamed: 7  acc                                        correctResp
# 0         NaN    0                 ['slang', ' slangenkop', ' snake']
# 1         NaN    0  ['waterkan', ' kan', ' fles', ' pitcher', 'kru...
# 2         NaN    0              ['sandwich', ' boterham', ' broodje']
# 3         NaN    0  ['kever', ' insect', ' beestje', ' wants', ' b...
# 4         NaN    0  ['trein', ' train', ' locomotief', ' wagon', '...

# %% [markdown]
# ## Check stimuli to be removed?

# %%
# groupby stim to see which stimuli are too difficult, don't give high enough diff score
print(len(df['stim'].unique()))

dfstim = df.groupby(['stim', 'prepost']).acc.mean() 
dfstim = dfstim.reset_index()
dfstim.head()
#dfstim.to_csv("AQ_Data/COaccByStim.csv")
# Out:
# 120
#                                                 stim prepost       acc
# 0  http://www.tureluurs.be/onlineExp/mooneyTD/img...    post  0.855346
# 1  http://www.tureluurs.be/onlineExp/mooneyTD/img...     pre  0.490566
# 2  http://www.tureluurs.be/onlineExp/mooneyTD/img...    post  0.153846
# 3  http://www.tureluurs.be/onlineExp/mooneyTD/img...     pre  0.000000
# 4  http://www.tureluurs.be/onlineExp/mooneyTD/img...    post  0.686275

# %%
# check stims that are too difficult

stims = dfstim.stim.loc[(dfstim.prepost=="post") & (dfstim.acc<.2)]

print(len(df))
print(len(stims))

for stim in stims:
    df = df[df.stim!=stim]

print(len(df))
print(len(df['stim'].unique()))
# Out:
# 36600
# 3
# 35686
# 117

# %% [markdown]
# ## Check individuals to be removed?

# %%
#groupby individuals
print(len(df['id'].unique()))

dfid = df.groupby(['id', "prepost"]).acc.mean()
dfid = dfid.reset_index()
dfid.head()

ids = dfid.id.loc[(dfid.prepost=="post") & (dfid.acc<.2)]

print(len(df))
print(len(ids))

for id in ids:
    df = df[df.id!=id]
    dfid = dfid[dfid.id!=id]

print(len(df))
print(len(df['id'].unique()))
# Out:
# 299
# 35686
# 14
# 34042
# 285

# %% [markdown]
# ## Merge AQ data and mooney data

# %%
dfAQ = pd.read_csv("AQ_Data/COdec2015AQ.csv")

# add AQ standardized scores
for i in ["AQ", "AQimagination","AQcomm", "AQsocialSkill", "AQattSwitch", "AQattDetail"]:
    dfAQ[i+"_s"] = (dfAQ[i] - dfAQ[i].mean()) / dfAQ[i].std()

# %%
dfmerged= pd.merge(df, dfAQ, how='outer', on='id')

print(len(dfmerged['id'].unique()))
dfmerged.head()
# Out:
# 303
#    Unnamed: 0_x       id  trialnb  blocknb prepost  \
# 0           0.0  20524.0      0.0      1.0     pre
# 1           1.0  20524.0      1.0      1.0     pre
# 2           2.0  20524.0      2.0      1.0     pre
# 3           3.0  20524.0      3.0      1.0     pre
# 4           4.0  20524.0      4.0      1.0     pre
#
#                                                 stim  response    rt  \
# 0  http://www.tureluurs.be/onlineExp/mooneyTD/img...  krokodil  3308
# 1  http://www.tureluurs.be/onlineExp/mooneyTD/img...     leeuw  2715
# 2  http://www.tureluurs.be/onlineExp/mooneyTD/img...      mens  3286
# 3  http://www.tureluurs.be/onlineExp/mooneyTD/img...       aap  3245
# 4  http://www.tureluurs.be/onlineExp/mooneyTD/img...      neus  2828
#
#    Unnamed: 7  acc      ...       AQsocialSkill  AQattSwitch  AQcomm  \
# 0         NaN  0.0      ...                20.0         24.0    21.0
# 1         NaN  0.0      ...                20.0         24.0    21.0
# 2         NaN  0.0      ...                20.0         24.0    21.0
# 3         NaN  0.0      ...                20.0         24.0    21.0
# 4         NaN  0.0      ...                20.0         24.0    21.0
#
#   AQimagination      AQ_s  AQimagination_s  AQcomm_s  AQsocialSkill_s  \
# 0          25.0 -0.713011         1.269891  0.083855        -0.247252
# 1          25.0 -0.713011         1.269891  0.083855        -0.247252
# 2          25.0 -0.713011         1.269891  0.083855        -0.247252
# 3          25.0 -0.713011         1.269891  0.083855        -0.247252
# 4          25.0 -0.713011         1.269891  0.083855        -0.247252
#
#    AQattSwitch_s  AQattDetail_s
# 0       0.023005      -0.534221
# 1       0.023005      -0.534221
# 2       0.023005      -0.534221
# 3       0.023005      -0.534221
# 4       0.023005      -0.534221
#
# [5 rows x 79 columns]

# %%
#drop rows without AQ or diff

dfmerged = dfmerged.dropna(subset=["AQ","prepost"])
print(len(dfmerged['id'].unique()))
dfmerged.head()
# Out:
# 282
#    Unnamed: 0_x       id  trialnb  blocknb prepost  \
# 0           0.0  20524.0      0.0      1.0     pre
# 1           1.0  20524.0      1.0      1.0     pre
# 2           2.0  20524.0      2.0      1.0     pre
# 3           3.0  20524.0      3.0      1.0     pre
# 4           4.0  20524.0      4.0      1.0     pre
#
#                                                 stim  response    rt  \
# 0  http://www.tureluurs.be/onlineExp/mooneyTD/img...  krokodil  3308
# 1  http://www.tureluurs.be/onlineExp/mooneyTD/img...     leeuw  2715
# 2  http://www.tureluurs.be/onlineExp/mooneyTD/img...      mens  3286
# 3  http://www.tureluurs.be/onlineExp/mooneyTD/img...       aap  3245
# 4  http://www.tureluurs.be/onlineExp/mooneyTD/img...      neus  2828
#
#    Unnamed: 7  acc      ...       AQsocialSkill  AQattSwitch  AQcomm  \
# 0         NaN  0.0      ...                20.0         24.0    21.0
# 1         NaN  0.0      ...                20.0         24.0    21.0
# 2         NaN  0.0      ...                20.0         24.0    21.0
# 3         NaN  0.0      ...                20.0         24.0    21.0
# 4         NaN  0.0      ...                20.0         24.0    21.0
#
#   AQimagination      AQ_s  AQimagination_s  AQcomm_s  AQsocialSkill_s  \
# 0          25.0 -0.713011         1.269891  0.083855        -0.247252
# 1          25.0 -0.713011         1.269891  0.083855        -0.247252
# 2          25.0 -0.713011         1.269891  0.083855        -0.247252
# 3          25.0 -0.713011         1.269891  0.083855        -0.247252
# 4          25.0 -0.713011         1.269891  0.083855        -0.247252
#
#    AQattSwitch_s  AQattDetail_s
# 0       0.023005      -0.534221
# 1       0.023005      -0.534221
# 2       0.023005      -0.534221
# 3       0.023005      -0.534221
# 4       0.023005      -0.534221
#
# [5 rows x 79 columns]

# %%
# compute proper ages
dfmerged.loc[:,"agec"] = dfmerged.age.str.split('/').str[-1]
dfmerged["agec"] = pd.to_numeric(dfmerged.agec, errors='coerce')
dfmerged.agec.loc[dfmerged.agec<50] = dfmerged.agec + 2000
dfmerged.agec.loc[(dfmerged.agec>50) & (dfmerged.agec<100)] = dfmerged.agec + 1900
dfmerged.agec.loc[dfmerged.agec == 7041996]=1996
dfmerged.agec = 2015 - dfmerged.agec
dfmerged.agec.loc[dfmerged.agec == 3] = 19 # invalid year

# %% [markdown]
# ## Add predicted memorability scores from net

# %%
dfmem = pd.read_csv("AQ_Data/mem_pred.csv", sep=';')
dfmem.head()
# Out:
#       stim  predicted_memorability
# 0  001.jpg                   0.630
# 1  002.jpg                   0.858
# 2  003.jpg                   0.736
# 3  004.jpg                   0.608
# 4  005.jpg                   0.865

# %%
dfmerged.loc[:,'stim'] = dfmerged['stim'].str.split('http://www.tureluurs.be/onlineExp/mooneyTD/img/tt/').str[1].str.replace('tt','')
dfmerged['stim'].head()
# Out:
# 0    429.jpg
# 1    350.jpg
# 2    867.jpg
# 3    812.jpg
# 4    573.jpg
# Name: stim, dtype: object

# %%
dfmerged= pd.merge(dfmerged, dfmem, how='outer', on='stim')

# %% [markdown]
# ## This is the final dataset

# %%
dfmerged.to_csv("AQ_Data/finalMerged.csv")

# %%
dfmerged = pd.read_csv("AQ_Data/finalMerged.csv")

# %% [markdown]
# ## Descriptive participant stats

# %%
pd.pivot_table(dfmerged, "acc", "id","prepost").describe().T
#pd.pivot_table(df, "acc", "id",["Group", "prepost"]).describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# prepost
# post     282.0  0.637336  0.139518  0.200000  0.559322  0.646595  0.741379
# pre      282.0  0.217780  0.085927  0.034483  0.157895  0.206897  0.271186
#
#               max
# prepost
# post     0.949153
# pre      0.550000

# %%
#Sex and age
sex = dfmerged.groupby(['id']).sex.apply(lambda x: x.iloc[0]) #number of males
print(len(sex[sex=="Man"]))
dfmerged.groupby(['id']).agec.mean().describe()
# Out:
# 40
# count    282.000000
# mean      18.602837
# std        1.908510
# min       17.000000
# 25%       18.000000
# 50%       18.000000
# 75%       19.000000
# max       39.000000
# Name: agec, dtype: float64

# %%
# AQlikert statistics
dfmerged.groupby(['id']).AQlikert.mean().describe().T
# Out:
# count    282.000000
# mean     108.657801
# std       14.684612
# min       71.000000
# 25%       99.000000
# 50%      108.000000
# 75%      117.750000
# max      158.000000
# Name: AQlikert, dtype: float64

# %%
# AQ(binary) statistics
dfmerged.groupby(['id']).AQ.mean().describe().T
# Out:
# count    282.000000
# mean      17.728723
# std        6.608389
# min        3.000000
# 25%       13.000000
# 50%       17.000000
# 75%       22.000000
# max       43.000000
# Name: AQ, dtype: float64

# %%
len(dfmerged[dfmerged.AQ >= 32].id.unique())  #number of scores above 32 (informal clinical cut-off)
# Out:
# 7

# %%
sns.distplot(dfmerged.groupby(['id']).AQ.mean(), bins=20);

# %% [markdown]
# ## Testing whether AQ is normally distributed

# %%
import scipy.stats as stats
print(stats.normaltest(dfmerged.groupby(['id']).AQ.mean()))
print(stats.kstest(dfmerged.groupby(['id']).AQ.mean(), 'norm'))

stats.probplot(dfmerged.groupby(['id']).AQ.mean(), dist="norm", plot=pylab);
# Out:
# NormaltestResult(statistic=16.024021248091977, pvalue=0.00033145761191318121)
# KstestResult(statistic=0.9986501019683699, pvalue=0.0)

# %% [markdown]
# ## Distribution of memorability scores

# %%
sns.distplot(dfmerged.groupby(['stim']).predicted_memorability.mean(), bins=20);

# %% [markdown]
# ## Is there improvement across blocks?

# %%
sns.set_context("poster")
sns.set_style("whitegrid")
f, ax = plt.subplots()
sns.barplot(x="blocknb", y="acc", hue="prepost", units="id",data=dfmerged);
ax.legend(title="", ncol=1, loc="upper left", fontsize='medium');
ax.set(ylabel="Mean accuracy", xlabel="Block", ylim=(0,.8));
save_fig(f, "AQblockAcc")

# %% [markdown]
# ## Plot median split AQ

# %%
#add variable median split
dfmerged['AQlevel']= pd.qcut(dfmerged['AQ'],2, labels=['Low AQ','High AQ'])
print(len(dfmerged[dfmerged.AQlevel=="Low AQ"]))
# Out:
# 18722

# %%
dfgrouped = dfmerged.groupby(['id', "prepost","AQlevel"]).acc.mean()
dfgrouped = dfgrouped.reset_index()
dfgrouped.head()
# Out:
#         id prepost  AQlevel       acc
# 0  18019.0    post   Low AQ  0.576271
# 1  18019.0     pre   Low AQ  0.186441
# 2  19756.0    post  High AQ  0.610169
# 3  19756.0     pre  High AQ  0.288136
# 4  20176.0    post  High AQ  0.711864

# %%
sns.set_context("poster")
sns.set_style("ticks")
f, ax = plt.subplots()
sns.violinplot(x="prepost", y="acc", hue="AQlevel", data=dfgrouped,inner="quartile",\
               split=True, order=["pre","post"]);
#sns.swarmplot(x="prepost", y="acc", hue="AQlevel", data=dfacc, color="w", alpha=.8);
labels = [item.get_text() for item in ax.get_xticklabels()]
labels[0] = 'Pre'
labels[1] = 'Post'
ax.set_xticklabels(labels)
sns.despine(offset=10, trim=True);
ax.legend(title="", ncol=1, loc="upper left", fontsize='medium');
ax.set(ylabel="Mean accuracy", xlabel="");
save_fig(f, "mediansplitAQ_acc_prepost")

# %%
# scatterplot of pre vs post accuracy
dfwide= pd.pivot_table(data=dfgrouped, values=["acc"], index=['id'],columns=['prepost']).reset_index()
dfwide.columns = [' '.join(col).strip() for col in dfwide.columns.values]
dfwide= pd.merge(dfwide, dfgrouped[['id','AQlevel']], how='inner', on='id').drop_duplicates(subset="id")
dfwide.head()

sns.lmplot(x="acc pre", y="acc post",hue="AQlevel", robust=True, data=dfwide);

# %% [markdown]
# ## Plot & test relation overall AQ score with Mooney performance

# %% [markdown]
# * McNeish, D., Stapleton, L. M., & Silverman, R. D. (2016). [On the Unnecessary Ubiquity of Hierarchical Linear Modeling. Psychological Methods](https://drive.google.com/open?id=0BwlD7q-DXkdWWXRWRG5YZUZ1elU). http://doi.org/10.1037/met0000078
#
# As an alternative method to deal with clustered data, GEEs have a few attractive advantages over hierarchical linear models (“mixed models”), for example fewer assumptions about the random effects and more intuitive interpretation of coefficients (McNeish, Stapleton, & Silverman, 2016). Especially for discrete dependent variables (i.e., our binary accuracy data) the likelihood-based mixed models can show difficult convergence and a lack of robustness to misspecification of the covariance structure.

# %%
# model formulation
fml = "acc ~ AQ_s * prepost * blocknb"

# covariance structure
ex = sm.cov_struct.Exchangeable()
#link fu
fa = sm.families.Binomial(sm.families.links.logit)

model = sm.GEE.from_formula(fml, "id", dfmerged, cov_struct=ex, family=fa)
result = model.fit()
print(result.summary())
print(result.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                         acc   No. Observations:                34156
# Model:                                 GEE   No. clusters:                      282
# Method:                        Generalized   Min. cluster size:                 114
#                       Estimating Equations   Max. cluster size:                 472
# Family:                           Binomial   Mean cluster size:               121.1
# Dependence structure:         Exchangeable   Num. iterations:                     8
# Date:                      zo, 08 jan 2017   Scale:                           1.001
# Covariance type:                    robust   Time:                         19:44:19
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.4878      0.054      9.055      0.000         0.382     0.593
# prepost[T.pre]                 -2.0706      0.051    -40.530      0.000        -2.171    -1.970
# AQ_s                           -0.0300      0.054     -0.553      0.580        -0.136     0.076
# AQ_s:prepost[T.pre]             0.0005      0.057      0.008      0.994        -0.111     0.112
# blocknb                         0.0217      0.011      1.912      0.056        -0.001     0.044
# prepost[T.pre]:blocknb          0.0644      0.012      5.390      0.000         0.041     0.088
# AQ_s:blocknb                   -0.0089      0.011     -0.798      0.425        -0.031     0.013
# AQ_s:prepost[T.pre]:blocknb     0.0107      0.013      0.790      0.429        -0.016     0.037
# ==============================================================================
# Skew:                          0.1762   Kurtosis:                      -1.0915
# Centered skew:                 0.1769   Centered kurtosis:             -0.9686
# ==============================================================================
# The correlation between two observations in the same cluster is 0.042

# %%
np.exp(-2.2719)
# Out:
# 0.1031160733013804

# %% [markdown]
# ## Testing interaction and main effect of AQ with R (glmer)
#
# First, we fit a model with and without the crucial interaction (prepost:AQ) predicting acc and use a likelihood ratio test to see whether the interaction is significant. We add the blocknb and the interaction blocknb:prepost to account for learning effects.

# %%
# %%R -i dfmerged
# m = glmer(acc ~ blocknb * prepost + sex + prepost * AQ_s + (prepost | id), dfmerged, family=binomial)
# m.null = glmer(acc ~ blocknb * prepost + sex + AQ_s + (prepost | id), dfmerged, family=binomial)
# lr.test(m, m.null, "interaction effect of prepost*AQ")
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: acc ~ blocknb * prepost + sex + prepost * AQ_s + (prepost | id)
#    Data: dfmerged
#
#      AIC      BIC   logLik deviance df.resid
#  39191.2  39275.6 -19585.6  39171.2    34146
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7698 -0.6092 -0.4238  0.7353  3.3305
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.32816  0.5728
#         prepostpre  0.04332  0.2081   -0.85
# Number of obs: 34156, groups:  id, 282
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)         0.497212   0.090817    5.47 4.38e-08 ***
# blocknb             0.022836   0.009658    2.36   0.0181 *
# prepostpre         -2.161781   0.059763  -36.17  < 2e-16 ***
# sexVrouw            0.032280   0.087767    0.37   0.7130
# AQ_s               -0.062138   0.037282   -1.67   0.0956 .
# blocknb:prepostpre  0.065760   0.014677    4.48 7.45e-06 ***
# prepostpre:AQ_s     0.033122   0.027968    1.18   0.2363
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp sexVrw AQ_s   blckn:
# blocknb     -0.370
# prepostpre  -0.328  0.562
# sexVrouw    -0.829  0.000  0.002
# AQ_s        -0.027 -0.001  0.005  0.024
# blcknb:prps  0.244 -0.658 -0.878  0.000  0.001
# prpstpr:AQ_  0.008  0.002 -0.003 -0.004 -0.593 -0.003
# convergence code: 0
# Model failed to converge with max|grad| = 0.00789659 (tol = 0.001, component 1)
#
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: acc ~ blocknb * prepost + sex + AQ_s + (prepost | id)
#    Data: dfmerged
#
#      AIC      BIC   logLik deviance df.resid
#  39190.6  39266.5 -19586.3  39172.6    34147
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7570 -0.6087 -0.4240  0.7372  3.3758
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.32902  0.5736
#         prepostpre  0.04454  0.2110   -0.84
# Number of obs: 34156, groups:  id, 282
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)         0.496412   0.090898    5.46 4.73e-08 ***
# blocknb             0.022818   0.009657    2.36   0.0181 *
# prepostpre         -2.161756   0.059803  -36.15  < 2e-16 ***
# sexVrouw            0.032732   0.087857    0.37   0.7095
# AQ_s               -0.036053   0.030184   -1.19   0.2323
# blocknb:prepostpre  0.065799   0.014677    4.48 7.36e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp sexVrw AQ_s
# blocknb     -0.370
# prepostpre  -0.328  0.562
# sexVrouw    -0.829  0.000  0.002
# AQ_s        -0.030  0.000  0.009  0.032
# blcknb:prps  0.244 -0.658 -0.877  0.000 -0.002
# convergence code: 0
# Model failed to converge with max|grad| = 0.00342135 (tol = 0.001, component 1)
#
# Likelihood ratio test for interaction effect of prepost*AQ:
#   Chisq(1) = 1.39; p = 0.238

# %%
# %%R
# anova(m, m.null)
# Out:
# Data: dfmerged
# Models:
# m.null: acc ~ blocknb * prepost + AQ_s + (prepost | id)
# m: acc ~ blocknb * prepost + prepost * AQ_s + (prepost | id)
#        Df   AIC   BIC logLik deviance  Chisq Chi Df Pr(>Chisq)
# m.null  8 39189 39256 -19586    39173
# m       9 39189 39265 -19586    39171 1.3975      1     0.2371

# %%
# %%R -i dfmerged
# m2 = glmer(acc ~ blocknb * prepost + sex + AQ_s + (prepost | id), dfmerged, family=binomial)
# m2.null = glmer(acc ~ blocknb * prepost + sex + (prepost | id), dfmerged, family=binomial)
# lr.test(m2, m2.null, "Main effect of AQ")
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: acc ~ blocknb * prepost + sex + AQ_s + (prepost | id)
#    Data: dfmerged
#
#      AIC      BIC   logLik deviance df.resid
#  39190.6  39266.5 -19586.3  39172.6    34147
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7570 -0.6087 -0.4240  0.7372  3.3758
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.32902  0.5736
#         prepostpre  0.04454  0.2110   -0.84
# Number of obs: 34156, groups:  id, 282
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)         0.496412   0.090898    5.46 4.73e-08 ***
# blocknb             0.022818   0.009657    2.36   0.0181 *
# prepostpre         -2.161756   0.059803  -36.15  < 2e-16 ***
# sexVrouw            0.032732   0.087857    0.37   0.7095
# AQ_s               -0.036053   0.030184   -1.19   0.2323
# blocknb:prepostpre  0.065799   0.014677    4.48 7.36e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp sexVrw AQ_s
# blocknb     -0.370
# prepostpre  -0.328  0.562
# sexVrouw    -0.829  0.000  0.002
# AQ_s        -0.030  0.000  0.009  0.032
# blcknb:prps  0.244 -0.658 -0.877  0.000 -0.002
# convergence code: 0
# Model failed to converge with max|grad| = 0.00342135 (tol = 0.001, component 1)
#
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: acc ~ blocknb * prepost + sex + (prepost | id)
#    Data: dfmerged
#
#      AIC      BIC   logLik deviance df.resid
#  39190.0  39257.5 -19587.0  39174.0    34148
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7619 -0.6090 -0.4241  0.7369  3.3406
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.33256  0.5767
#         prepostpre  0.04465  0.2113   -0.85
# Number of obs: 34156, groups:  id, 282
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)         0.493265   0.090950    5.42 5.85e-08 ***
# blocknb             0.022819   0.009657    2.36   0.0181 *
# prepostpre         -2.161428   0.059799  -36.14  < 2e-16 ***
# sexVrouw            0.035984   0.087889    0.41   0.6822
# blocknb:prepostpre  0.065774   0.014676    4.48 7.40e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp sexVrw
# blocknb     -0.369
# prepostpre  -0.328  0.562
# sexVrouw    -0.829  0.000  0.002
# blcknb:prps  0.243 -0.658 -0.877  0.000
# convergence code: 0
# Model failed to converge with max|grad| = 0.00176545 (tol = 0.001, component 1)
#
# Likelihood ratio test for Main effect of AQ:
#   Chisq(1) = 1.43; p = 0.233

# %%
# %%R -i dfmerged
# m3 = glmer(acc ~ prepost + (1 | id), dfmerged, family=binomial)
# m3.null = glmer(acc ~ 1 + (1 | id), dfmerged, family=binomial)
# lr.test(m, m.null, "Main effect of prepost")

# %% [markdown]
# Print the final model

# %%
# %R print(m, corr=FALSE)
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: acc ~ prepost + (prepost | id)
#    Data: dfmerged
#       AIC       BIC    logLik  deviance  df.resid
#  39254.37  39296.56 -19622.18  39244.37     34151
# Random effects:
#  Groups Name        Std.Dev. Corr
#  id     (Intercept) 0.5762
#         prepostpre  0.2114   -0.85
# Number of obs: 34156, groups:  id, 282
# Fixed Effects:
# (Intercept)   prepostpre
#      0.6037      -1.9246

# %% [markdown]
# ## Fitting a generalized linear mixed model with bambi (Bayesian inference)
#
# [bambi](https://github.com/bambinos/bambi)

# %%
# Specify how the Bernoulli p parameter is distributed
prior_p = Prior('Beta', alpha=2, beta=2)

# The response variable distribution
prior = Prior('Bernoulli', p=prior_p)

# Construct the family
new_fam = Family('binomial', prior=prior, link="logit", parent='p')

# %%
# %timeit

# Now it's business as usual
model = Model(dfmerged)
results = model.fit('acc ~ prepost * AQ_s', random='1|id', family=new_fam, samples=1000)
# Out:
# Applied log-transform to u_id_sd and added transformed u_id_sd_log_ to model.
# Assigned NUTS to b_Intercept
# INFO (theano.gof.compilelock): Refreshing lock /home/sander/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/lock_dir/lock
# INFO:theano.gof.compilelock:Refreshing lock /home/sander/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/sander/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/lock_dir/lock
# INFO:theano.gof.compilelock:Refreshing lock /home/sander/.theano/compiledir_Linux-4.4--generic-x86_64-with-Ubuntu-16.04-xenial-x86_64-2.7.12-64/lock_dir/lock
# Assigned NUTS to b_prepost
# Assigned NUTS to b_AQ
# Assigned NUTS to b_prepost:AQ
# Assigned NUTS to u_id_sd_log_
# Assigned NUTS to u_id
#  [-------100%-------] 1000 of 1000 in 7031.6 sec. | SPS: 0.1 | ETA: 0.0

# %%
results.summary(500)

# %%
results.plot(burn_in=500);

# %% [markdown]
# ## Compute diff scores for regular glm and plotting

# %%
dfmeans = dfmerged.groupby(['id', "prepost"]).acc.mean()
dfmeans = dfmeans.unstack().reset_index()
dfmeans["diff"] = dfmeans.post - dfmeans.pre
dfmeansAQ= dfmeans.merge(dfAQ, how='left', on='id')
# remove duplicates
dfmeansAQ = dfmeansAQ.drop_duplicates(subset="id")
print(len(dfmeansAQ))
dfmeansAQ.head()
# Out:
# 282
# prepost       id      post       pre      diff  Unnamed: 0  Unnamed: 0.1  \
# 0        18019.0  0.576271  0.186441  0.389831         146           146
# 1        19756.0  0.610169  0.288136  0.322034           4             4
# 2        20176.0  0.711864  0.237288  0.474576         272           272
# 3        20179.0  0.593220  0.203390  0.389831         185           185
# 4        20191.0  0.568966  0.103448  0.465517         240           240
#
# prepost    sex         age  agec  1      ...        AQsocialSkill  \
# 0        Vrouw       11/96   NaN  3      ...                   21
# 1        Vrouw       10/96   NaN  4      ...                   26
# 2        Vrouw  19/06/1997   NaN  3      ...                   27
# 3        Vrouw  24/01/1997   NaN  2      ...                   18
# 4        Vrouw     04/1997   NaN  3      ...                   25
#
# prepost  AQattSwitch  AQcomm  AQimagination      AQ_s  AQimagination_s  \
# 0                 22      22             21 -0.097549         0.371425
# 1                 26      21             17  0.671779        -0.527041
# 2                 28      28             20  1.287241         0.146808
# 3                 24      19             16  0.210182        -0.751658
# 4                 28      23             21  0.210182         0.371425
#
# prepost  AQcomm_s  AQsocialSkill_s  AQattSwitch_s  AQattDetail_s
# 0        0.323664        -0.017285      -0.462476       1.138124
# 1        0.083855         1.132548       0.508486       1.347167
# 2        1.762516         1.362514       0.993967      -0.116135
# 3       -0.395763        -0.707185       0.023005       0.720038
# 4        0.563472         0.902581       0.993967      -1.370394
#
# [5 rows x 72 columns]

# %% [markdown]
# ## Check if raw number of responses correlates with AQ imagination

# %%
dfacc = dfmerged.groupby(['id', "prepost"]).acc.mean().reset_index()
respcount = dfmerged.groupby(["id", "prepost"]).response.count().reset_index()
dfcount = pd.merge(dfacc, respcount, on=["id","prepost"])
dfcount = dfcount.merge(dfAQ, how='left', on='id')
dfcount.head()
# Out:
#         id prepost       acc  response  Unnamed: 0  Unnamed: 0.1    sex  \
# 0  18019.0    post  0.576271        49         146           146  Vrouw
# 1  18019.0     pre  0.186441        42         146           146  Vrouw
# 2  19756.0    post  0.610169        59           4             4  Vrouw
# 3  19756.0     pre  0.288136        59           4             4  Vrouw
# 4  20176.0    post  0.711864        59         272           272  Vrouw
#
#           age  agec  1      ...        AQsocialSkill  AQattSwitch  AQcomm  \
# 0       11/96   NaN  3      ...                   21           22      22
# 1       11/96   NaN  3      ...                   21           22      22
# 2       10/96   NaN  4      ...                   26           26      21
# 3       10/96   NaN  4      ...                   26           26      21
# 4  19/06/1997   NaN  3      ...                   27           28      28
#
#    AQimagination      AQ_s  AQimagination_s  AQcomm_s  AQsocialSkill_s  \
# 0             21 -0.097549         0.371425  0.323664        -0.017285
# 1             21 -0.097549         0.371425  0.323664        -0.017285
# 2             17  0.671779        -0.527041  0.083855         1.132548
# 3             17  0.671779        -0.527041  0.083855         1.132548
# 4             20  1.287241         0.146808  1.762516         1.362514
#
#    AQattSwitch_s  AQattDetail_s
# 0      -0.462476       1.138124
# 1      -0.462476       1.138124
# 2       0.508486       1.347167
# 3       0.508486       1.347167
# 4       0.993967      -0.116135
#
# [5 rows x 72 columns]

# %%
f = sns.jointplot(x="AQimagination", y="response", data=dfcount, kind="reg");

# %%
model = smf.glm(formula="diff ~ AQ", data=dfmeansAQ)
results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   diff   No. Observations:                  282
# Model:                            GLM   Df Residuals:                      280
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                 0.0105566562614
# Method:                          IRLS   Log-Likelihood:                 242.55
# Date:                Fri, 16 Sep 2016   Deviance:                       2.9559
# Time:                        02:33:10   Pearson chi2:                     2.96
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.4468      0.018     25.478      0.000         0.412     0.481
# AQ            -0.0015      0.001     -1.658      0.097        -0.003     0.000
# ==============================================================================

# %%
# plotting correlation

sns.set_context("poster")
sns.set_style("white")

f = sns.jointplot(x="AQ", y="diff", data=dfmeansAQ, kind="reg");
sns.axlabel("AQ","Difference score")
save_fig(f, "AQ_diff_scatter")

# %% [markdown]
# ## Plot & test relation AQ subscales with Mooney performance

# %%
#subscale effects

# model formulation
fml = "acc ~ AQattDetail + AQattDetail:prepost + AQattSwitch + AQattSwitch:prepost + AQcomm + AQcomm:prepost \
+ AQsocialSkill + AQsocialSkill:prepost + AQimagination + AQimagination:prepost + prepost + \
blocknb + blocknb*prepost + sex"

# covariance structure
ex = sm.cov_struct.Exchangeable()
#link fu
fa = sm.families.Binomial(sm.families.links.logit)

model = sm.GEE.from_formula(fml, "id", dfmerged, cov_struct=ex, family=fa)
result = model.fit()
print(result.summary())
print(result.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                         acc   No. Observations:                34156
# Model:                                 GEE   No. clusters:                      282
# Method:                        Generalized   Min. cluster size:                 114
#                       Estimating Equations   Max. cluster size:                 472
# Family:                           Binomial   Mean cluster size:               121.1
# Dependence structure:         Exchangeable   Num. iterations:                     9
# Date:                      wo, 21 sep 2016   Scale:                           1.000
# Covariance type:                    robust   Time:                         03:03:37
# ================================================================================================
#                                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        1.1364      0.274      4.155      0.000         0.600     1.673
# prepost[T.pre]                  -2.4415      0.216    -11.300      0.000        -2.865    -2.018
# sex[T.Vrouw]                     0.0634      0.099      0.640      0.522        -0.131     0.258
# AQattDetail                     -0.0010      0.007     -0.142      0.887        -0.015     0.013
# AQattDetail:prepost[T.pre]       0.0014      0.005      0.267      0.789        -0.009     0.012
# AQattSwitch                     -0.0277      0.010     -2.693      0.007        -0.048    -0.008
# AQattSwitch:prepost[T.pre]       0.0081      0.008      1.023      0.306        -0.007     0.024
# AQsocialSkill                    0.0349      0.010      3.335      0.001         0.014     0.055
# AQsocialSkill:prepost[T.pre]    -0.0062      0.008     -0.739      0.460        -0.023     0.010
# AQimagination                   -0.0388      0.009     -4.412      0.000        -0.056    -0.022
# AQimagination:prepost[T.pre]     0.0137      0.007      1.965      0.049       3.8e-05     0.027
# blocknb                          0.0216      0.011      1.887      0.059        -0.001     0.044
# blocknb:prepost[T.pre]           0.0649      0.012      5.392      0.000         0.041     0.088
# ==============================================================================
# Skew:                          0.1802   Kurtosis:                      -1.0733
# Centered skew:                 0.1806   Centered kurtosis:             -0.9616
# ==============================================================================
# The correlation between two observations in the same cluster is 0.039

# %%
model = smf.glm(formula="diff ~ AQimagination + AQattDetail + AQattSwitch + AQcomm + AQsocialSkill", data=dfmeansAQ)
results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   diff   No. Observations:                  282
# Model:                            GLM   Df Residuals:                      276
# Model Family:                Gaussian   Df Model:                            5
# Link Function:               identity   Scale:                 0.0102799215046
# Method:                          IRLS   Log-Likelihood:                 248.33
# Date:                Fri, 16 Sep 2016   Deviance:                       2.8373
# Time:                        02:56:40   Pearson chi2:                     2.84
# No. Iterations:                     4
# =================================================================================
#                     coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         0.5239      0.048     10.927      0.000         0.430     0.618
# AQimagination    -0.0050      0.002     -3.220      0.001        -0.008    -0.002
# AQattDetail      -0.0005      0.001     -0.434      0.664        -0.003     0.002
# AQattSwitch      -0.0037      0.002     -2.070      0.038        -0.007    -0.000
# AQcomm            0.0025      0.002      1.164      0.244        -0.002     0.007
# AQsocialSkill     0.0020      0.002      1.014      0.310        -0.002     0.006
# =================================================================================

# %%
sns.set_context("poster")
sns.set_style("white")

f = sns.jointplot(x="AQimagination", y="diff", data=dfmeansAQ, kind="reg", robust=True);
sns.axlabel("AQ imagination","difference score")
save_fig(f,"imagination_diff_scatter")

# %%
f = sns.jointplot(x="AQattSwitch", y="diff", data=dfmeansAQ, kind="reg");

# %%
# compute individual overall acc for plotting
dfgenmeans = dfmerged.groupby(['id']).acc.mean()
dfgenmeans = dfgenmeans.reset_index()
dfgenmeansAQ= dfgenmeans.merge(dfAQ, how='left', on='id')
# remove duplicates
dfgenmeansAQ = dfgenmeansAQ.drop_duplicates(subset="id")
print(len(dfgenmeansAQ))
dfgenmeansAQ.head()
# Out:
# 282
#       id       acc  Unnamed: 0  Unnamed: 0.1    sex         age  agec  1  2  \
# 0  18019  0.381356         146           146  Vrouw       11/96   NaN  3  1
# 1  19756  0.449153           4             4  Vrouw       10/96   NaN  4  2
# 2  20176  0.474576         272           272  Vrouw  19/06/1997   NaN  3  1
# 3  20179  0.398305         185           185  Vrouw  24/01/1997   NaN  2  2
# 4  20191  0.336207         240           240  Vrouw     04/1997   NaN  3  3
#
#    3      ...        48  49  50  AQ  AQlikert  AQattDetail  AQsocialSkill  \
# 0  2      ...         1   2   3  17       115           29             21
# 1  1      ...         2   1   2  22       120           30             26
# 2  2      ...         2   1   2  26       126           23             27
# 3  1      ...         2   3   1  19       104           27             18
# 4  2      ...         2   2   3  19       114           17             25
#
#    AQattSwitch  AQcomm  AQimagination
# 0           22      22             21
# 1           26      21             17
# 2           28      28             20
# 3           24      19             16
# 4           28      23             21
#
# [5 rows x 64 columns]

# %%
f = sns.jointplot(x="AQimagination", y="pre", data=dfmeansAQ, kind="reg");
sns.axlabel("AQ imagination","Pre accuracy")
save_fig(f, "imagination_pre_scatter")

f = sns.jointplot(x="AQimagination", y="post", data=dfmeansAQ, kind="reg");
sns.axlabel("AQ imagination","Post accuracy")
save_fig(f,"imagination_post_scatter")

f = sns.jointplot(x="AQimagination", y="acc", data=dfgenmeansAQ, kind="reg");
sns.axlabel("AQ imagination","Overall accuracy")
save_fig(f,"imagination_genacc_scatter")

# %%
sns.pairplot(dfmeansAQ[["pre","AQattDetail", "AQsocialSkill", "AQattSwitch", "AQcomm", "AQimagination"]]);

# %%
dfmeans = dfmerged.groupby(['stim', "prepost"]).acc.mean()
dfmeans = dfmeans.unstack().reset_index()
dfmeans["diff"] = dfmeans.post - dfmeans.pre
dfmeansMem= dfmeans.merge(dfmem, how='left', on='stim')
# remove duplicates
dfmeansMem = dfmeansMem.drop_duplicates(subset="stim")
print(len(dfmeansMem))
dfmeansMem.head()
# Out:
# 117
# prepost     stim      post       pre      diff  predicted_memorability
# 0        001.jpg  0.890323  0.522581  0.367742                   0.630
# 1        003.jpg  0.729167  0.138889  0.590278                   0.736
# 2        004.jpg  0.543624  0.120805  0.422819                   0.608
# 3        005.jpg  0.838926  0.476510  0.362416                   0.865
# 4        006.jpg  0.870130  0.266234  0.603896                   0.736

# %%
f = sns.jointplot(x="predicted_memorability", y="diff", data=dfmeansMem, kind="reg");

# %% [markdown]
# # Study 2: Comparing Mooney performance in participants with ASD and TD controls
#
# **!!! Don't run this again, import preprocessed, merged data below (starting section 3.6) !!!**

# %% [markdown]
# ## Preprocessing mooneyTD

# %%
# From raw data to dataframe

with open('MooneyDataRawASD.csv', 'Ur') as f:
    data = list(list(rec) for rec in csv.reader(f, delimiter='\t'))

expandata=[]

print(len(data))
expandata.append(["id", "trialnb", "blocknb", "prepost", "stim", "response", "rt"])

#print(data[1][2])


for i,row in enumerate(data):
    
    
    if i==0:
        continue
    else:
        trials=row[2].split(']')
        
        
        for trial in trials:
            
            trial = trial.strip('[]')
            if trial=="": continue
            trial = trial.split(',')            
            expandata.append(trial)

print(len(expandata))

with open("datMooneyTD.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(expandata)
# Out:
# 80
# 9481

# %% [markdown]
# ## Read in preprocessed data and run correction key

# %%
df = pd.read_csv("dataMooney-aangepast.csv",)
df.head()
# Out:
#     id  trialnb  blocknb prepost  \
# 0  102        0        0     pre
# 1  102        1        0     pre
# 2  102        2        0     pre
# 3  102        3        0     pre
# 4  102        4        0     pre
#
#                                                 stim response    rt
# 0  http://www.sandervandecruys.be/onlineExp/moone...     hond  5391
# 1  http://www.sandervandecruys.be/onlineExp/moone...      man  7805
# 2  http://www.sandervandecruys.be/onlineExp/moone...    vrouw  7894
# 3  http://www.sandervandecruys.be/onlineExp/moone...     hond  7165
# 4  http://www.sandervandecruys.be/onlineExp/moone...   strand  5215

# %%
def correct(df):


    rk = pd.read_csv("mooneyanswerkey.csv",delimiter='\t')
    acccol = []
    correctRespcol = []
    
    
    for rowNb, row in df.iterrows():


        answer = str(row['response'])
        acc=0
        
        

        if answer!='':
            answer=answer.lower()

            img= row['stim']
            
            
            img=img.split('http://www.sandervandecruys.be/onlineExp/mooneyTD/')
        
            img=img[1].strip('"')
            
            sols= rk.sol[rk['tt'] == img]
            sols=np.array(sols)[0].split(',')
            correctResp=sols

            for i in sols:
                i.strip()
                if fuzz.ratio(i,answer) > 70:
                    acc=1
                    break

        acccol.append(acc)
        correctRespcol.append(correctResp)

    df['acc'] = acccol
    df['correctResp'] = correctRespcol
    #print acccol
    return df

df = correct(df)
df.head()
df.to_csv('dataMooneyTDwithAcc.csv')

# %% [markdown]
# ## Preprocessing done

# %%
df= pd.read_csv('ASD_Data/dataMooneyTDwithAcc.csv')

df.head()
# Out:
#    Unnamed: 0   id  trialnb  blocknb prepost  \
# 0           0  102        0        0     pre
# 1           1  102        1        0     pre
# 2           2  102        2        0     pre
# 3           3  102        3        0     pre
# 4           4  102        4        0     pre
#
#                                                 stim response      rt  acc  \
# 0  http://www.sandervandecruys.be/onlineExp/moone...     hond  5391.0    0
# 1  http://www.sandervandecruys.be/onlineExp/moone...      man  7805.0    0
# 2  http://www.sandervandecruys.be/onlineExp/moone...    vrouw  7894.0    0
# 3  http://www.sandervandecruys.be/onlineExp/moone...     hond  7165.0    0
# 4  http://www.sandervandecruys.be/onlineExp/moone...   strand  5215.0    0
#
#                                          correctResp
# 0               ['kikker', ' pad', ' toad', ' frog']
# 1  ['hagedis', ' kameleon', ' leguaan', ' lizard'...
# 2                 ['uil', ' owl', ' vogel', ' bird']
# 3  ['luipaard', ' jachtluipaard', ' jaguar', ' le...
# 4                         ['kangoeroe', ' kangaroo']

# %% [markdown]
# ## Merge descriptive data with experimental data

# %%
dfDescriptive = pd.read_excel("ASD_Data/DescriptiveData.xls")
dfmerged= pd.merge(df, dfDescriptive, on='id')
print(len(dfmerged['id'].unique()))
print(len(dfmerged))
dfmerged.to_csv('ASD_Data/dataMooneywithDescriptive.csv')
df= dfmerged
df["blocknb"]=df.blocknb + 1 #block starts from 0 instead of 1
df.head()
# Out:
# 49
# 5880
#    Unnamed: 0   id  trialnb  blocknb prepost  \
# 0           0  102        0        1     pre
# 1           1  102        1        1     pre
# 2           2  102        2        1     pre
# 3           3  102        3        1     pre
# 4           4  102        4        1     pre
#
#                                                 stim response      rt  acc  \
# 0  http://www.sandervandecruys.be/onlineExp/moone...     hond  5391.0    0
# 1  http://www.sandervandecruys.be/onlineExp/moone...      man  7805.0    0
# 2  http://www.sandervandecruys.be/onlineExp/moone...    vrouw  7894.0    0
# 3  http://www.sandervandecruys.be/onlineExp/moone...     hond  7165.0    0
# 4  http://www.sandervandecruys.be/onlineExp/moone...   strand  5215.0    0
#
#                                          correctResp          ...           \
# 0               ['kikker', ' pad', ' toad', ' frog']          ...
# 1  ['hagedis', ' kameleon', ' leguaan', ' lizard'...          ...
# 2                 ['uil', ' owl', ' vogel', ' bird']          ...
# 3  ['luipaard', ' jachtluipaard', ' jaguar', ' le...          ...
# 4                         ['kangoeroe', ' kangaroo']          ...
#
#      TIQ  VIQ  PIQ SRS_overall SRS_consciousness  SRS_Cognition  \
# 0  107.0   97  117          37                37             41
# 1  107.0   97  117          37                37             41
# 2  107.0   97  117          37                37             41
# 3  107.0   97  117          37                37             41
# 4  107.0   97  117          37                37             41
#
#    SRS_Communication  SRS_Motivation  SRS_Preoccupation  ADOS: Above cut-off?
# 0                 37              38                 45                   NaN
# 1                 37              38                 45                   NaN
# 2                 37              38                 45                   NaN
# 3                 37              38                 45                   NaN
# 4                 37              38                 45                   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Explore data: should we exclude people?

# %%
for i, v in enumerate(df.columns):
    print(i, v)
print(df.dtypes)
# Out:
# 0 Unnamed: 0
# 1 id
# 2 trialnb
# 3 blocknb
# 4 prepost
# 5 stim
# 6 response
# 7 rt
# 8 acc
# 9 correctResp
# 10 Initials
# 11 Age
# 12 Gender
# 13 Handedness
# 14 Group
# 15 TIQ
# 16 VIQ
# 17 PIQ
# 18 SRS_overall
# 19 SRS_consciousness
# 20 SRS_Cognition
# 21 SRS_Communication
# 22 SRS_Motivation
# 23 SRS_Preoccupation
# 24 ADOS: Above cut-off?
# Unnamed: 0                int64
# id                        int64
# trialnb                   int64
# blocknb                   int64
# prepost                  object
# stim                     object
# response                 object
# rt                      float64
# acc                       int64
# correctResp              object
# Initials                 object
# Age                       int64
# Gender                   object
# Handedness               object
# Group                    object
# TIQ                     float64
# VIQ                       int64
# PIQ                       int64
# SRS_overall               int64
# SRS_consciousness         int64
# SRS_Cognition             int64
# SRS_Communication         int64
# SRS_Motivation            int64
# SRS_Preoccupation         int64
# ADOS: Above cut-off?     object
# dtype: object

# %%
idmeans= df.groupby('id').acc.mean()
idmeans[idmeans<.2]
# Out:
# id
# 204    0.108333
# 229    0.100000
# Name: acc, dtype: float64

# %% [markdown]
# **Participant 204 and 229 gave up early in the task and so did not reach .2 accuracy. They will be excluded from the rest of the analyses**

# %%
df= df.loc[df.id!=204]
df= df.loc[df.id!=229]

# %%
plt.figure(figsize=(8, 6))
f, ax = plt.subplots()
sns.pointplot(x="prepost", y="acc", hue="Group", units="id",data=df, dodge=True);
ax.legend(title="", ncol=1, loc="upper left", fontsize='medium');
ax.set(ylabel="Mean accuracy", xlabel="Group", ylim=(0,.9));
save_fig(f, "ASD_group_acc")

# %% [markdown]
# ## This is the final dataset

# %%
df.to_csv("ASD_Data/finalASDMerged.csv")

# %%
df = pd.read_csv("ASD_Data/finalASDMerged.csv")

# %% [markdown]
# ## Descriptive stats
#
# Summarize accuracy data

# %%
pd.pivot_table(df, "acc", "id","prepost").describe().T
#pd.pivot_table(df, "acc", "id",["Group", "prepost"]).describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# prepost
# post      47.0  0.752128  0.111999  0.466667  0.683333  0.766667  0.833333
# pre       47.0  0.280496  0.101755  0.016667  0.225000  0.283333  0.350000
#
#               max
# prepost
# post     0.933333
# pre      0.500000

# %%
#Gender
sex = df.groupby(['id']).Gender.apply(lambda x: x.iloc[0]) #number of males
print(len(sex[sex=="Man"]))


for i in ['Age', 'SRS_overall', 'TIQ', 'PIQ', 'VIQ']:
    grouped = df.groupby(['id','Group'])[i].mean().reset_index()
    print (grouped.groupby(['Group'])[i].describe())
    out = ttest_ind(grouped[grouped.Group=="ASD"][i], grouped[grouped.Group=="TD"][i], \
                    alternative='two-sided', usevar='pooled')
    print(i, "t-statistic:", out[0], "p-value:", out[1], "df:", out[2])
# Out:
# 39
# Group
# ASD    count    23.000000
#        mean     14.043478
#        std       1.491743
#        min      11.000000
#        25%      13.000000
#        50%      14.000000
#        75%      15.000000
#        max      17.000000
# TD     count    24.000000
#        mean     14.375000
#        std       1.279011
#        min      13.000000
#        25%      13.000000
#        50%      14.000000
#        75%      15.000000
#        max      17.000000
# Name: Age, dtype: float64
# Age t-statistic: -0.81907990544 p-value: 0.417057697716 df: 45.0
# Group
# ASD    count     23.000000
#        mean      80.260870
#        std       11.454326
#        min       57.000000
#        25%       72.000000
#        50%       80.000000
#        75%       83.000000
#        max      104.000000
# TD     count     24.000000
#        mean      49.458333
#        std        9.107948
#        min       37.000000
#        25%       44.250000
#        50%       48.500000
#        75%       56.250000
#        max       67.000000
# Name: SRS_overall, dtype: float64
# SRS_overall t-statistic: 10.2269591993 p-value: 2.56249537115e-13 df: 45.0
# Group
# ASD    count     23.000000
#        mean     104.326087
#        std        8.738120
#        min       83.000000
#        25%      102.000000
#        50%      105.500000
#        75%      110.000000
#        max      116.000000
# TD     count     24.000000
#        mean     105.958333
#        std        8.692721
#        min       84.500000
#        25%      102.250000
#        50%      107.250000
#        75%      111.750000
#        max      119.500000
# Name: TIQ, dtype: float64
# TIQ t-statistic: -0.641861945811 p-value: 0.524219181552 df: 45.0
# Group
# ASD    count     23.000000
#        mean     108.086957
#        std       14.403008
#        min       77.000000
#        25%      102.000000
#        50%      111.000000
#        75%      115.500000
#        max      132.000000
# TD     count     24.000000
#        mean     106.000000
#        std       12.293512
#        min       77.000000
#        25%       99.250000
#        50%      104.500000
#        75%      114.750000
#        max      126.000000
# Name: PIQ, dtype: float64
# PIQ t-statistic: 0.53507781004 p-value: 0.595230484649 df: 45.0
# Group
# ASD    count     23.000000
#        mean     102.869565
#        std       15.392750
#        min       65.000000
#        25%       94.500000
#        50%      103.000000
#        75%      112.500000
#        max      140.000000
# TD     count     24.000000
#        mean     105.833333
#        std        7.602440
#        min       84.000000
#        25%      103.000000
#        50%      108.000000
#        75%      111.000000
#        max      116.000000
# Name: VIQ, dtype: float64
# VIQ t-statistic: -0.842398806208 p-value: 0.404019844482 df: 45.0

# %% [markdown]
# ## Do response counts (or false guesses) differ between phases/groups?

# %%
accsum = df.groupby(["id", "Group", "prepost"]).acc.sum().reset_index()
respcount = df.groupby(["id", "Group", "prepost"]).response.count().reset_index()
fa = pd.merge(accsum, respcount, on=["id","Group","prepost"])
fa["falseGuesses"] = fa.response-fa.acc
fa.head()
# Out:
#     id Group prepost  acc  response  falseGuesses
# 0  102    TD    post   45        60            15
# 1  102    TD     pre   17        60            43
# 2  103    TD    post   28        60            32
# 3  103    TD     pre   12        60            48
# 4  104    TD    post   54        58             4

# %%
lm = smf.ols("falseGuesses ~ prepost*Group", data=fa).fit()
table = sm.stats.anova_lm(lm, typ=2)
print(table)
lm = smf.ols("response ~ prepost*Group", data=fa).fit()
table = sm.stats.anova_lm(lm, typ=2)
print(table)
# Out:
#                      sum_sq    df           F        PR(>F)
# prepost        10766.340426   1.0  151.753813  5.141447e-21
# Group            145.746608   1.0    2.054329  1.552390e-01
# prepost:Group     14.253777   1.0    0.200910  6.550646e-01
# Residual        6385.148551  90.0         NaN           NaN
#                     sum_sq    df          F    PR(>F)
# prepost        1116.765957   1.0  11.515971  0.001028
# Group           131.284690   1.0   1.353794  0.247691
# prepost:Group    27.567376   1.0   0.284272  0.595229
# Residual       8727.786232  90.0        NaN       NaN

# %%
sns.violinplot(x="prepost", y="falseGuesses", hue="Group",data=fa, inner="stick", dodge=True, order=("pre","post"));

# %%
sns.violinplot(x="prepost", y="response", hue="Group",data=fa, inner="stick", dodge=True, order=("pre","post"));

# %% [markdown]
# ## Does performance (acc) depend on group, prepost and/or block?

# %%
sns.factorplot(x="blocknb", y="acc",hue='Group', col='prepost', units="id",data=df, dodge=True);

# %%
# model formulation
fml = "acc ~ prepost * Group + blocknb" 
#"+ SRS_overall + SRS_overall:Group + TIQ + TIQ:Group"

ex = sm.cov_struct.Exchangeable() # covariance structure
fa = sm.families.Binomial(sm.families.links.logit) #link fu
model = sm.GEE.from_formula(fml, "id", df, cov_struct=ex, family=fa)
result = model.fit()

print(result.summary())
print(result.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                         acc   No. Observations:                 5640
# Model:                                 GEE   No. clusters:                       47
# Method:                        Generalized   Min. cluster size:                 120
#                       Estimating Equations   Max. cluster size:                 120
# Family:                           Binomial   Mean cluster size:               120.0
# Dependence structure:         Exchangeable   Num. iterations:                     6
# Date:                      za, 24 sep 2016   Scale:                           1.002
# Covariance type:                    robust   Time:                         01:50:20
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.6916      0.140      4.942      0.000         0.417     0.966
# prepost[T.pre]                -2.1034      0.103    -20.358      0.000        -2.306    -1.901
# Group[T.TD]                   -0.0414      0.177     -0.233      0.815        -0.389     0.306
# prepost[T.pre]:Group[T.TD]     0.0539      0.154      0.350      0.727        -0.248     0.356
# blocknb                        0.1310      0.027      4.794      0.000         0.077     0.185
# ==============================================================================
# Skew:                         -0.0348   Kurtosis:                      -0.8357
# Centered skew:                -0.0258   Centered kurtosis:             -0.7603
# ==============================================================================
# The correlation between two observations in the same cluster is 0.037

# %%
# model formulation
fml = "acc ~ prepost * Group + blocknb + blocknb*prepost + blocknb*Group + TIQ +\
 SRS_consciousness*prepost + SRS_Cognition*prepost + SRS_Communication*prepost +\
 SRS_Motivation*prepost + SRS_Preoccupation*prepost"

ex = sm.cov_struct.Exchangeable() # covariance structure
fa = sm.families.Binomial(sm.families.links.logit) #link fu
model = sm.GEE.from_formula(fml, "id", df, cov_struct=ex, family=fa)
result = model.fit()

print(result.summary())
print(result.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                         acc   No. Observations:                 5640
# Model:                                 GEE   No. clusters:                       47
# Method:                        Generalized   Min. cluster size:                 120
#                       Estimating Equations   Max. cluster size:                 120
# Family:                           Binomial   Mean cluster size:               120.0
# Dependence structure:         Exchangeable   Num. iterations:                    15
# Date:                      vr, 23 sep 2016   Scale:                           1.007
# Covariance type:                    robust   Time:                         03:00:26
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -1.4577      1.151     -1.267      0.205        -3.713     0.798
# prepost[T.pre]                      -3.1249      0.586     -5.334      0.000        -4.273    -1.977
# Group[T.TD]                         -0.0690      0.391     -0.176      0.860        -0.835     0.697
# prepost[T.pre]:Group[T.TD]           0.3725      0.264      1.413      0.158        -0.144     0.889
# blocknb                              0.1292      0.040      3.224      0.001         0.051     0.208
# blocknb:prepost[T.pre]               0.0170      0.032      0.538      0.591        -0.045     0.079
# blocknb:Group[T.TD]                 -0.0118      0.055     -0.216      0.829        -0.119     0.095
# TIQ                                  0.0209      0.006      3.333      0.001         0.009     0.033
# SRS_consciousness                   -0.0090      0.011     -0.800      0.424        -0.031     0.013
# SRS_consciousness:prepost[T.pre]     0.0193      0.010      2.022      0.043         0.001     0.038
# SRS_Cognition                       -0.0039      0.010     -0.380      0.704        -0.024     0.016
# SRS_Cognition:prepost[T.pre]         0.0064      0.009      0.719      0.472        -0.011     0.024
# SRS_Communication                    0.0025      0.010      0.254      0.800        -0.017     0.021
# SRS_Communication:prepost[T.pre]     0.0028      0.007      0.419      0.675        -0.010     0.016
# SRS_Motivation                       0.0029      0.007      0.401      0.689        -0.011     0.017
# SRS_Motivation:prepost[T.pre]        0.0014      0.007      0.209      0.834        -0.011     0.014
# SRS_Preoccupation                    0.0066      0.008      0.828      0.407        -0.009     0.022
# SRS_Preoccupation:prepost[T.pre]    -0.0158      0.009     -1.700      0.089        -0.034     0.002
# ==============================================================================
# Skew:                         -0.0297   Kurtosis:                      -0.8170
# Centered skew:                -0.0284   Centered kurtosis:             -0.7613
# ==============================================================================
# The correlation between two observations in the same cluster is 0.033

# %%
# odds ratio: 
# http://stats.stackexchange.com/questions/133623/help-me-understand-adjusted-odds-ratio-in-logistic-regression
oddsratio = 1- (1/(1+np.exp(-2.088)))
oddsratio

# %% [markdown]
# ## GLMM of main effect Group & interaction effect Group*prepost

# %%
# %%R -i df
# m = glmer(acc ~ blocknb + blocknb*prepost + prepost * Group + TIQ + SRS_overall + (prepost | id), df, family=binomial)
# m.null = glmer(acc ~ blocknb + blocknb*prepost + prepost + Group + TIQ + SRS_overall + (prepost | id), df, family=binomial)
# lr.test(m, m.null, "interaction effect of prepost*Group")
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# acc ~ blocknb + blocknb * prepost + prepost * Group + TIQ + SRS_overall +
#     (prepost | id)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6328.4   6401.4  -3153.2   6306.4     5629
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1610 -0.6550  0.3652  0.6027  3.2828
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.2306   0.4802
#         prepostpre  0.1249   0.3534   -0.45
# Number of obs: 5640, groups:  id, 47
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -1.760099   1.183648  -1.487   0.1370
# blocknb             0.128698   0.026434   4.869 1.12e-06 ***
# prepostpre         -2.282598   0.174015 -13.117  < 2e-16 ***
# GroupTD             0.147451   0.273824   0.538   0.5902
# TIQ                 0.018677   0.008740   2.137   0.0326 *
# SRS_overall         0.007066   0.007119   0.993   0.3209
# blocknb:prepostpre  0.015702   0.036632   0.429   0.6682
# prepostpre:GroupTD  0.076986   0.163261   0.472   0.6372
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp GropTD TIQ    SRS_vr blckn:
# blocknb     -0.073
# prepostpre  -0.055  0.502
# GroupTD     -0.518  0.002  0.157
# TIQ         -0.873 -0.002 -0.022  0.120
# SRS_overall -0.645  0.002 -0.005  0.791  0.212
# blcknb:prps  0.046 -0.722 -0.735 -0.001  0.009  0.000
# prpstpr:GTD  0.037  0.001 -0.485 -0.336  0.005 -0.003  0.000
# convergence code: 0
# Model failed to converge with max|grad| = 0.0623533 (tol = 0.001, component 1)
# Model is nearly unidentifiable: very large eigenvalue
#  - Rescale variables?
# Model is nearly unidentifiable: large eigenvalue ratio
#  - Rescale variables?
#
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# acc ~ blocknb + blocknb * prepost + prepost + Group + TIQ + SRS_overall +
#     (prepost | id)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6326.6   6393.0  -3153.3   6306.6     5630
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1881 -0.6537  0.3675  0.6000  3.2527
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.2311   0.4808
#         prepostpre  0.1263   0.3554   -0.46
# Number of obs: 5640, groups:  id, 47
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -1.790817   1.180783  -1.517    0.129
# blocknb             0.128692   0.026434   4.868 1.12e-06 ***
# prepostpre         -2.243202   0.152302 -14.729  < 2e-16 ***
# GroupTD             0.192198   0.258119   0.745    0.457
# TIQ                 0.018727   0.008731   2.145    0.032 *
# SRS_overall         0.007109   0.007110   1.000    0.317
# blocknb:prepostpre  0.015722   0.036632   0.429    0.668
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp GropTD TIQ    SRS_vr
# blocknb     -0.074
# prepostpre  -0.043  0.574
# GroupTD     -0.529  0.003 -0.006
# TIQ         -0.874 -0.002 -0.022  0.119
# SRS_overall -0.646  0.002 -0.008  0.838  0.212
# blcknb:prps  0.046 -0.722 -0.839 -0.002  0.010  0.000
# convergence code: 0
# Model failed to converge with max|grad| = 0.0172367 (tol = 0.001, component 1)
# Model is nearly unidentifiable: very large eigenvalue
#  - Rescale variables?
# Model is nearly unidentifiable: large eigenvalue ratio
#  - Rescale variables?
#
# Likelihood ratio test for interaction effect of prepost*Group:
#   Chisq(1) = 0.22; p = 0.637

# %%
# %%R
# print(anova(m, m.null))

# %%
# %%R -i df
# m = glmer(acc ~ blocknb + blocknb*prepost + prepost + Group + TIQ + SRS_overall + (prepost | id), df, family=binomial)
# m.null = glmer(acc ~ blocknb + blocknb*prepost + prepost + TIQ + SRS_overall + (prepost | id), df, family=binomial)
# lr.test(m, m.null, "Main effect of Group")
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# acc ~ blocknb + blocknb * prepost + prepost + Group + TIQ + SRS_overall +
#     (prepost | id)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6326.6   6393.0  -3153.3   6306.6     5630
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1881 -0.6537  0.3675  0.6000  3.2527
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.2311   0.4808
#         prepostpre  0.1263   0.3554   -0.46
# Number of obs: 5640, groups:  id, 47
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -1.790817   1.180783  -1.517    0.129
# blocknb             0.128692   0.026434   4.868 1.12e-06 ***
# prepostpre         -2.243202   0.152302 -14.729  < 2e-16 ***
# GroupTD             0.192198   0.258119   0.745    0.457
# TIQ                 0.018727   0.008731   2.145    0.032 *
# SRS_overall         0.007109   0.007110   1.000    0.317
# blocknb:prepostpre  0.015722   0.036632   0.429    0.668
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp GropTD TIQ    SRS_vr
# blocknb     -0.074
# prepostpre  -0.043  0.574
# GroupTD     -0.529  0.003 -0.006
# TIQ         -0.874 -0.002 -0.022  0.119
# SRS_overall -0.646  0.002 -0.008  0.838  0.212
# blcknb:prps  0.046 -0.722 -0.839 -0.002  0.010  0.000
# convergence code: 0
# Model failed to converge with max|grad| = 0.0172367 (tol = 0.001, component 1)
# Model is nearly unidentifiable: very large eigenvalue
#  - Rescale variables?
# Model is nearly unidentifiable: large eigenvalue ratio
#  - Rescale variables?
#
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: acc ~ blocknb + blocknb * prepost + prepost + TIQ + SRS_overall +
#     (prepost | id)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6325.2   6384.9  -3153.6   6307.2     5631
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1766 -0.6564  0.3676  0.6007  3.2558
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.2305   0.4801
#         prepostpre  0.1251   0.3536   -0.44
# Number of obs: 5640, groups:  id, 47
#
# Fixed effects:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -1.343972   1.004972  -1.337   0.1811
# blocknb             0.128666   0.026430   4.868 1.13e-06 ***
# prepostpre         -2.243173   0.152198 -14.738  < 2e-16 ***
# TIQ                 0.018113   0.008697   2.083   0.0373 *
# SRS_overall         0.002698   0.003903   0.691   0.4894
# blocknb:prepostpre  0.015798   0.036630   0.431   0.6663
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) blcknb prpstp TIQ    SRS_vr
# blocknb     -0.084
# prepostpre  -0.053  0.574
# TIQ         -0.962 -0.003 -0.022
# SRS_overall -0.438 -0.001 -0.006  0.206
# blcknb:prps  0.053 -0.722 -0.840  0.010  0.003
# convergence code: 0
# Model failed to converge with max|grad| = 0.00101099 (tol = 0.001, component 1)
# Model is nearly unidentifiable: very large eigenvalue
#  - Rescale variables?
# Model is nearly unidentifiable: large eigenvalue ratio
#  - Rescale variables?
#
# Likelihood ratio test for Main effect of Group:
#   Chisq(1) = 0.56; p = 0.453

# %%
# %%R -i df
# m = glmer(acc ~ prepost + (prepost | id), df, family=binomial)
# m.null = glmer(acc ~ 1 + (prepost | id), df, family=binomial)
# lr.test(m, m.null, "Main effect of prepost")
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: acc ~ prepost + (prepost | id)
#    Data: df
#
#      AIC      BIC   logLik deviance df.resid
#   6378.1   6411.3  -3184.1   6368.1     5635
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7241 -0.6578  0.3691  0.5772  2.8264
#
# Random effects:
#  Groups Name        Variance Std.Dev. Corr
#  id     (Intercept) 0.2736   0.5230
#         prepostpre  0.1216   0.3487   -0.53
# Number of obs: 5640, groups:  id, 47
#
# Fixed effects:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  1.17610    0.08927   13.18   <2e-16 ***
# prepostpre  -2.16199    0.08160  -26.49   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#            (Intr)
# prepostpre -0.578
# Likelihood ratio test for Main effect of prepost:
#   Chisq(1) = 132.47; p = 1.18e-30

# %% [markdown]
# ## Fitting a generalized linear mixed model with bambi (Bayesian inference)

# %%
# Specify how the Bernoulli p parameter is distributed
prior_p = Prior('Beta', alpha=2, beta=2)

# The response variable distribution
prior = Prior('Bernoulli', p=prior_p)

# Construct the family
new_fam = Family('binomial', prior=prior, link="logit", parent='p')
# Specify how the Bernoulli p parameter is distributed
prior_p = Prior('Beta', alpha=2, beta=2)

# The response variable distribution
prior = Prior('Bernoulli', p=prior_p)

# Construct the family
new_fam = Family('binomial', prior=prior, link="logit", parent='p')

# %%
# %timeit

# Now it's business as usual
model = Model(df)
results = model.fit('acc ~ prepost * Group * blocknb', random='prepost|id', family=new_fam, samples=3000)
# Out:
# Applied log-transform to u_id_sd and added transformed u_id_sd_log_ to model.
# Applied log-transform to u_prepost|id_prepost_sd and added transformed u_prepost|id_prepost_sd_log_ to model.
# Assigned NUTS to b_Intercept
# Assigned NUTS to b_prepost
# Assigned NUTS to b_Group
# Assigned NUTS to b_prepost:Group
# Assigned NUTS to b_blocknb
# Assigned NUTS to b_prepost:blocknb
# Assigned NUTS to b_Group:blocknb
# Assigned NUTS to b_prepost:Group:blocknb
# Assigned NUTS to u_id_sd_log_
# Assigned NUTS to u_id
# Assigned NUTS to u_prepost|id_prepost_sd_log_
# Assigned NUTS to u_prepost|id_prepost
#  [-------100%-------] 3000 of 3000 in 1261.5 sec. | SPS: 2.4 | ETA: 0.0
# /usr/local/lib/python2.7/dist-packages/bambi/models.py:218: UserWarning: Current Bayesian model has not been built yet; building it first before sampling begins.
#   warnings.warn("Current Bayesian model has not been built yet; "

# %%
results.summary(1000)

# %%
results.plot(burn_in=1000);

# %% [markdown]
# ## Interim conclusion
#
# * There is a clear effect of the exposure to the "templates".
# * There is also a learning effect (blocknb), but this is mainly carried by worse performance in the first block. Little learning happens after that. The learning effect is similar across phases (no interaction blocknb*phases) and groups (no interaction blocknb*group)
# * There is no significant group effect or group*phase interaction.
# * These conclusions hold also when correcting for IQ (matched) and SRS scores. IQ (specifically PIQ) may have an influence (see below).
# * **The use of prior (top-down) information is not reduced or increased in ASD.**

# %% [markdown]
# ## Compute diff scores (postmean minus premean)

# %%
print(len(df['id'].unique()))

def diffScore(df):
    
    after = df[df.prepost=='post'].acc.mean()
    before = df[df.prepost=='pre'].acc.mean()
    countsPre= df[df.prepost=='pre'].response.count()
    countsPost= df[df.prepost=='post'].response.count()
    fa= (df[df.prepost=='pre'].acc.sum())/float(countsPre)
    diff= after - before 
    SRS_overall = df['SRS_consciousness'].iloc[0]
    PIQ = df['PIQ'].iloc[0]
    TIQ = df['TIQ'].iloc[0]    
    group = df['Group'].iloc[0]
    #df['id'].iloc[0]
    dfout = pd.DataFrame(data=[(group, PIQ, TIQ, SRS_overall, before, after, diff, countsPre, countsPost, fa)], \
                         columns=['group','PIQ', 'TIQ','SRS_consciousness','pre', 'post', 'diff', \
                                  'countsPre', 'countsPost', 'fa'])
    return dfout

dfdiff = df.groupby('id').apply(diffScore)
dfdiff = dfdiff.reset_index()
dfdiff.head()
# Out:
# 47
#     id  level_1 group  PIQ    TIQ  SRS_consciousness       pre      post  \
# 0  102        0    TD  117  107.0                 37  0.283333  0.750000
# 1  103        0    TD  114  111.5                 47  0.200000  0.466667
# 2  104        0    TD  123  115.5                 40  0.400000  0.900000
# 3  105        0    TD  103  107.0                 40  0.116667  0.650000
# 4  106        0    TD  100  101.5                 49  0.233333  0.866667
#
#        diff  countsPre  countsPost        fa
# 0  0.466667         60          60  0.283333
# 1  0.266667         60          60  0.200000
# 2  0.500000         49          58  0.489796
# 3  0.533333         52          59  0.134615
# 4  0.633333         58          60  0.241379

# %% [markdown]
# ## Statistical test on the diff scores and on counts

# %%
# GLM test on diff score

model = smf.glm(formula="diff ~ group * SRS_overall * PIQ", data=dfdiff)

results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   diff   No. Observations:                   47
# Model:                            GLM   Df Residuals:                       39
# Model Family:                Gaussian   Df Model:                            7
# Link Function:               identity   Scale:                0.00966927690589
# Method:                          IRLS   Log-Likelihood:                 46.707
# Date:                Sat, 17 Sep 2016   Deviance:                      0.37710
# Time:                        01:14:56   Pearson chi2:                    0.377
# No. Iterations:                     4
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.2147      1.795     -0.120      0.905        -3.733     3.304
# group[T.TD]                     1.5695      2.179      0.720      0.471        -2.700     5.839
# SRS_overall                     0.0111      0.022      0.503      0.615        -0.032     0.054
# group[T.TD]:SRS_overall        -0.0376      0.033     -1.127      0.260        -0.103     0.028
# PIQ                             0.0061      0.016      0.373      0.709        -0.026     0.038
# group[T.TD]:PIQ                -0.0134      0.020     -0.666      0.505        -0.053     0.026
# SRS_overall:PIQ              -9.82e-05      0.000     -0.493      0.622        -0.000     0.000
# group[T.TD]:SRS_overall:PIQ     0.0003      0.000      1.049      0.294        -0.000     0.001
# ===============================================================================================

# %%
# GLM test of counts

model = smf.glm(formula="countsPre ~ group * SRS_overall * PIQ", data=dfdiff)
results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              countsPre   No. Observations:                   47
# Model:                            GLM   Df Residuals:                       39
# Model Family:                Gaussian   Df Model:                            7
# Link Function:               identity   Scale:                   178.752309283
# Method:                          IRLS   Log-Likelihood:                -184.18
# Date:                Fri, 16 Sep 2016   Deviance:                       6971.3
# Time:                        23:37:16   Pearson chi2:                 6.97e+03
# No. Iterations:                     4
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                    -249.4742    244.086     -1.022      0.307      -727.874   228.926
# group[T.TD]                   196.8514    296.203      0.665      0.506      -383.696   777.399
# SRS_overall                     3.2852      2.989      1.099      0.272        -2.572     9.143
# group[T.TD]:SRS_overall        -1.3675      4.538     -0.301      0.763       -10.261     7.526
# PIQ                             2.5301      2.211      1.144      0.252        -1.803     6.863
# group[T.TD]:PIQ                -1.6698      2.727     -0.612      0.540        -7.014     3.674
# SRS_overall:PIQ                -0.0276      0.027     -1.020      0.308        -0.081     0.025
# group[T.TD]:SRS_overall:PIQ     0.0120      0.042      0.283      0.777        -0.071     0.095
# ===============================================================================================

# %% [markdown]
# ## Make violin plots for inspecting differences and distributions

# %%
# reshape data
dfmelted = pd.melt(dfdiff, id_vars=['id','group'], value_vars=['pre', 'post'], var_name=["prepost"], value_name='acc')
dfmelted.head()
# Out:
#     id group prepost       acc
# 0  102    TD     pre  0.283333
# 1  103    TD     pre  0.200000
# 2  104    TD     pre  0.400000
# 3  105    TD     pre  0.116667
# 4  106    TD     pre  0.233333

# %%
sns.set_context("poster")
sns.set_style("ticks")
f, ax = plt.subplots()
sns.violinplot(x="prepost", y="acc", hue="group", data=dfmelted, split=True, inner="stick");
labels = [item.get_text() for item in ax.get_xticklabels()]
labels[0] = 'Pre'
labels[1] = 'Post'
ax.set_xticklabels(labels)
sns.despine(offset=10, trim=True);
ax.legend(title="", ncol=1, loc="upper left", fontsize='medium');
ax.set(ylabel="Mean accuracy", xlabel="");
save_fig(f,"ASD_acc_prepost")

# %%
# plot individual data (diff scores)
sns.swarmplot(x="group", y="diff", data=dfdiff);

# %%
# scatterplot of pre vs post accuracy ("paired observations")
dfwide= pd.pivot_table(data=dfmelted, values=["acc"], index=['id'],columns=['prepost']).reset_index()
dfwide.columns = [' '.join(col).strip() for col in dfwide.columns.values]
dfwide= pd.merge(dfwide, dfmelted[['id','group']], how='inner', on='id').drop_duplicates(subset="id")
dfwide.head()
sns.lmplot(x="acc pre", y="acc post",hue="group", robust=True, data=dfwide);

# %%
# Plotting paired observations per id
sns.set_context("paper")
sns.factorplot(x="prepost", y="acc",hue="id", col="group", kind="point",\
               join=True, legend=False, palette=sns.color_palette("PuBuGn_d"), data=dfmelted)

# %% [markdown]
# ## Check correlations with SRS

# %%
# plotting correlation

sns.set_context("poster")
sns.set_style("white")
sns.lmplot(x="SRS_consciousness", y="diff", hue='group', data=dfdiff);
f = sns.jointplot(x="SRS_consciousness", y="diff", data=dfdiff[dfdiff.group!="ASD"], kind="reg");
save_fig(f,"SRS_consciousness_diff_scatter")

# %%
sns.jointplot(x="SRS_overall", y="countsPost", data=dfdiff, kind="reg");
sns.lmplot(x="SRS_overall", y="countsPost", hue='group', data=dfdiff);

# %% [markdown]
# ## Interim conclusion
#
# * No notable correlations between SRS_overall & diff, pre/postmean, counts

# %% [markdown]
# ## Check correlations with IQ

# %%
sns.jointplot(x="PIQ", y="diff", data=dfdiff, kind="reg");
sns.lmplot(x="PIQ", y="diff", hue='group', data=dfdiff);
sns.jointplot(x="PIQ", y="post", data=dfdiff, kind="reg");
sns.lmplot(x="PIQ", y="post", hue='group', data=dfdiff);

# %%
sns.jointplot(x="PIQ", y="countsPre", data=dfdiff, kind="reg");
sns.lmplot(x="PIQ", y="countsPost", hue='group', data=dfdiff);
