# %% [markdown]
# # Analyses MooneyTD task in AQ trait (students) and ASD (adolescents)
#
# **Researchers: Sander Van de Cruys, Ines Van de Put (MA thesis student), Steven Vanmarcke (data collection), Johan Wagemans**
# ___
#
#
# Notes:
# * All errorbars are **95% CIs**
# * Task order: Mooney (pretest, exposure phase, posttest; "MooneyTD"), learning uncertain environment
# * dependent vars: recognition acc and count (number of guesses irrespective of accurate recognition, could also give a measure of "top-down generative strength").
#
#
# * 1s target duration
# * 2s template duration
# * 750ms iti
#
#
# Mooney task based on:
#
# > Teufel, C., Subramaniam, N., Dobler, V., Perez, J., Finnemann, J., Mehta, P. R., … Fletcher, P. C. (2015). Shift toward prior knowledge confers a perceptual advantage in early psychosis and psychosis-prone healthy individuals. Proceedings of the National Academy of Sciences of the United States of America, 112(43), 13401–13406.
#
# *Study 1*:
#
# * About 300 subjects (students)
# * AQ traits measured
#
# *Study 2*:
#
# * 25 participants in each group (adolescents, matched on IQ and gender by Steven)
# * notes: 223 (under ados cutoff) & 204/229 (acc lower than .2)

# %%
import numpy as np
import pandas as pd
import csv, json
from fuzzywuzzy import fuzz

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from __future__ import print_function
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std


# %pylab inline
sns.set(style="whitegrid", color_codes=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Study 1: Correlating AQ with Mooney performance

# %% [markdown]
# ## Scoring AQ

# %%
#starting from raw google form data

df = pd.read_csv("AQ_Data/AQCOdec2015.csv")

labels = ["id","sex","age"]

items= [str(x+1) for x in range(50)]
labels=labels+items

df.columns = labels

# %%
#starting from clean data
df = pd.read_csv("AQ_Data/COdec2015AQ.csv")
df.head()

# %%
repsOptions= {"Definitely agree":1, "Slightly agree": 2, 
              "Slightly disagree":3, "Definitely disagree":4}


qLow= [1, 2, 4, 5, 6, 7, 9, 12, 13, 16, 18, 19, 20, 21, 22, 23, 26, 33, 35, 
       39, 41, 42, 43, 45, 46]

qHigh= [3, 8, 10, 11, 14, 15, 17, 24, 25, 27, 28, 29, 30, 31, 32, 34, 36, 
        37, 38, 40, 44, 47, 48, 49, 50]

# items for subscales: Baron-Cohen
socialskill = [1,11,13,15,22,36,44,45,47,48] 
attswitch = [2,4,10,16,25,32,34,37,43,46] 
attdetail = [5,6,9,12,19,23,28,29,30,49] 
comm = [7,17,18,26,27,31,33,35,38,39] 
imagination = [3,8,14,20,21,24,40,41,42,50]

""" In the first major trial using the test, 
the average score in the control group was 16.4. 
Eighty percent of those diagnosed with autism or 
a related disorder scored 32 or higher. 
The test is not a means for making a diagnosis, 
however, and many who score above 32 and even 
meet the diagnostic criteria for mild autism or 
Asperger’s report no difficulty functioning 
.in their everyday lives. from http://aspergerstest.net/interpreting-aq-test-results/"""

def scoreBC(row):
    """ score binary like original Baron-Cohen"""
    aqscore=0
    
    for i in qLow:
        if row[str(i)] <=2 :
            aqscore+=1
        
    for i in qHigh:
        if row[str(i)] > 2 :
            aqscore+=1
            
               
    return aqscore

def scoreLikert(row):
    """ score 4-point likert """
    likertscore=0
    
    for i in qLow:
        likertscore += 5-row[str(i)]
        
    for i in qHigh:
        likertscore += row[str(i)]
            
               
    return likertscore

def scoresubscale(row, sub):
    """ score on nonsocial items"""
    
    subscore=0
    
    for i in sub:
        if i in qLow:
            subscore += 5-row[str(i)]

        if i in qHigh:
            subscore += row[str(i)]

               
    return subscore

df['AQ'] = df.apply(scoreBC, axis=1)
df['AQlikert'] = df.apply(scoreLikert, axis=1)
df['AQattDetail'] = df.apply(scoresubscale, axis=1, args=([attdetail]))
df['AQsocialSkill'] = df.apply(scoresubscale, axis=1, args=([socialskill]))
df['AQattSwitch'] = df.apply(scoresubscale, axis=1, args=([attswitch]))
df['AQcomm'] = df.apply(scoresubscale, axis=1, args=([comm]))
df['AQimagination'] = df.apply(scoresubscale, axis=1, args=([imagination]))

# %%
df[['id','AQ']]
df.to_csv("AQ_Data/COdec2015AQ.csv")

df.head()

# %% [markdown]
# ## Preprocessing mooneyTD

# %%
with open('AQ_Data/mooneyTDCOdec2015.csv', 'Ur') as f:
    data = list(list(rec) for rec in csv.reader(f, delimiter='\t'))

expandata=[]

print len(data)
expandata.append(["id", "trialnb", "blocknb", "prepost", "stim", "response", "rt"])

#print data[1][2]


for i,row in enumerate(data):
    
    
    if i==0:
        continue
    else:
        trials=row[2].split('\n')
        
        for trial in trials:
            
            trial = trial.strip('[]')
            if trial=="": continue
            trial = trial.split(',')            
            expandata.append(trial)

print len(expandata)

with open("AQ_Data/datMooneyTD.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(expandata)

# %% [markdown]
# ## Correct responses with answer key

# %%
df = pd.read_csv("AQ_Data/datMooneyTD.csv")


def correct(df):


    rk = pd.read_csv("mooneyanswerkey.csv",delimiter='\t')
    acccol = []
    correctRespcol = []
        
    
    for rowNb, row in df.iterrows():


        answer = str(row['response'])
        acc=0
        

        if answer!='':
            answer=answer.lower()

            img= row['stim']

            img=img.split('http://www.tureluurs.be/onlineExp/mooneyTD/')
        
            img=img[1].strip('"')
            
            sols= rk.sol[rk['tt'] == img]
            sols=np.array(sols)[0].split(',')
            correctResp=sols

            for i in sols:
                i.strip()
                if fuzz.ratio(i,answer) > 70:
                    acc=1
                    break

        acccol.append(acc)
        correctRespcol.append(correctResp)

    df['acc'] = acccol
    df['correctResp'] = correctRespcol
    #print acccol
    return df    

df = correct(df)
df.head()
df.to_csv('AQ_Data/dataMooneyTDwithAcc.csv')

# %%
df= pd.read_csv('AQ_Data/dataMooneyTDwithAcc.csv')
sns.pointplot(x="prepost", y="acc",units="id",data=df);
df.head()
# Out:
#    Unnamed: 0     id  trialnb  blocknb prepost  \
# 0           0  20524        0        0     pre
# 1           1  20524        1        0     pre
# 2           2  20524        2        0     pre
# 3           3  20524        3        0     pre
# 4           4  20524        4        0     pre
#
#                                                 stim  response    rt  \
# 0  http://www.tureluurs.be/onlineExp/mooneyTD/img...  krokodil  3308
# 1  http://www.tureluurs.be/onlineExp/mooneyTD/img...     leeuw  2715
# 2  http://www.tureluurs.be/onlineExp/mooneyTD/img...      mens  3286
# 3  http://www.tureluurs.be/onlineExp/mooneyTD/img...       aap  3245
# 4  http://www.tureluurs.be/onlineExp/mooneyTD/img...      neus  2828
#
#    Unnamed: 7  acc                                        correctResp
# 0         NaN    0                 ['slang', ' slangenkop', ' snake']
# 1         NaN    0  ['waterkan', ' kan', ' fles', ' pitcher', 'kru...
# 2         NaN    0              ['sandwich', ' boterham', ' broodje']
# 3         NaN    0  ['kever', ' insect', ' beestje', ' wants', ' b...
# 4         NaN    0  ['trein', ' train', ' locomotief', ' wagon', '...

# %%
# groupby stim to see which stimuli are too difficult, don't give high enough diff score
print(len(df['stim'].unique()))


def diffScore(df):
    
    postm = df[df.prepost=='post'].acc.mean()
    prem = df[df.prepost=='pre'].acc.mean()
    
    diff= postm - prem 
    
    #df['id'].iloc[0]
    dfout = pd.DataFrame(data=[(prem, postm, diff)], columns=['prem', 'postm', 'diff'])
    
    return dfout

dfstim = df.groupby('stim').apply(diffScore)
dfstim = dfstim.reset_index()
dfstim.to_csv("AQ_Data/COaccByStim.csv")
# Out:
# 120

# %%
# check stims that are too difficult

stims = df.groupby(['stim']).mean()
stims = stims.reset_index()
stims = stims.stim[stims.acc<.2]#.iloc[0]

print(len(df))

for stim in stims:
    df = df[df.stim!=stim]

print(len(df))
# Out:
# 36600
# 32672

# %%
print(len(df['id'].unique()))


def diffScore(df):
    
    postm = df[df.prepost=='post'].acc.mean()
    prem = df[df.prepost=='pre'].acc.mean()
    
    diff= postm - prem 
    
    #df['id'].iloc[0]
    dfout = pd.DataFrame(data=[(prem, postm, diff)], columns=['prem', 'postm', 'diff'])
    
    return dfout

dfdiff = df.groupby('id').apply(diffScore)
dfdiff = dfdiff.reset_index()
# Out:
# 299

# %%
# simple plots:
dfdiff.head()
dfdiff = dfdiff[dfdiff.postm>.2]
dfmelted = pd.melt(dfdiff, id_vars=['id'], value_vars=['prem', 'postm','diff'], var_name=["prepost"], value_name='acc')
dfmelted.head()
#sns.stripplot(x="prepost", y="acc",data=dfmelted)
sns.violinplot(x="prepost", y="acc", data=dfmelted);
sns.pointplot(x="prepost", y="acc", data=dfmelted);

# %%
print(len(dfdiff['id'].unique()))
# Out:
# 285

# %% [markdown]
# ## Merge AQ data and mooney data

# %%
dfAQ = pd.read_csv("AQ_Data/COdec2015AQ.csv")

dfmerged= pd.merge(dfdiff, dfAQ, how='outer', on='id')

print(len(dfmerged['id'].unique()))
dfmerged.head()
# Out:
# 303
#       id  level_1      prem     postm      diff  Unnamed: 0  Unnamed: 0.1  \
# 0    999        0  0.254545  0.800000  0.545455         NaN           NaN
# 1  18019        0  0.203704  0.611111  0.407407         146           146
# 2  19756        0  0.303571  0.642857  0.339286           4             4
# 3  20176        0  0.259259  0.740741  0.481481         272           272
# 4  20179        0  0.222222  0.592593  0.370370         185           185
#
#      sex         age   1      ...        48  49  50  AQ  AQlikert  \
# 0    NaN         NaN NaN      ...       NaN NaN NaN NaN       NaN
# 1  Vrouw       11/96   3      ...         1   2   3  17       115
# 2  Vrouw       10/96   4      ...         2   1   2  22       120
# 3  Vrouw  19/06/1997   3      ...         2   1   2  26       126
# 4  Vrouw  24/01/1997   2      ...         2   3   1  19       104
#
#    AQattDetail  AQsocialSkill  AQattSwitch  AQcomm  AQimagination
# 0          NaN            NaN          NaN     NaN            NaN
# 1           29             21           22      22             21
# 2           30             26           26      21             17
# 3           23             27           28      28             20
# 4           27             18           24      19             16
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Analysis of correlations between Mooney & AQ scales

# %%
#drop rows without AQ or diff

dfmerged = dfmerged.dropna(subset=["AQ","diff"])
print(len(dfmerged['id'].unique()))
dfmerged.head()
# Out:
# 282
#       id  level_1      prem     postm      diff  Unnamed: 0  Unnamed: 0.1  \
# 1  18019        0  0.203704  0.611111  0.407407         146           146
# 2  19756        0  0.303571  0.642857  0.339286           4             4
# 3  20176        0  0.259259  0.740741  0.481481         272           272
# 4  20179        0  0.222222  0.592593  0.370370         185           185
# 5  20191        0  0.115385  0.615385  0.500000         240           240
#
#      sex         age  1      ...        48  49  50  AQ  AQlikert  AQattDetail  \
# 1  Vrouw       11/96  3      ...         1   2   3  17       115           29
# 2  Vrouw       10/96  4      ...         2   1   2  22       120           30
# 3  Vrouw  19/06/1997  3      ...         2   1   2  26       126           23
# 4  Vrouw  24/01/1997  2      ...         2   3   1  19       104           27
# 5  Vrouw     04/1997  3      ...         2   2   3  19       114           17
#
#    AQsocialSkill  AQattSwitch  AQcomm  AQimagination
# 1             21           22      22             21
# 2             26           26      21             17
# 3             27           28      28             20
# 4             18           24      19             16
# 5             25           28      23             21
#
# [5 rows x 66 columns]

# %%
# remove outliers: low acc on posttest

dfmerged = dfmerged[dfmerged.postm>.4]
print (len(dfmerged['id'].unique()))

df.to_csv("AQ_Data/COdec2015AQMooneyMerged.csv")
# Out:
# 267

# %%
#add variable median split


print(dfmerged.AQ.median())
print(dfmerged.AQ.mean())
print(dfmerged.AQ.std())
print(dfmerged.AQ.max())
print(dfmerged.AQ.min())
print(dfmerged.AQ.quantile([0,.25,.5,.75,1.]))

dfmerged['AQlevel']= pd.qcut(dfmerged['AQlikert'],2, labels=['lowAQ','highAQ'])
dfmerged.head()
print(len(dfmerged[dfmerged.AQlevel=="mHighAQ"]))
dfmerged[dfmerged.AQ==43]
# Out:
# 17.0
# 17.637037037
# 6.52773027657
# 43.0
# 3.0
# 0.00     3
# 0.25    13
# 0.50    17
# 0.75    21
# 1.00    43
# Name: AQ, dtype: float64
# 0
#         id  level_1   prem     postm      diff  Unnamed: 0  Unnamed: 0.1  \
# 119  20710        0  0.125  0.482143  0.357143          73            73
#
#        sex    age  1   ...     49  50  AQ  AQlikert  AQattDetail  \
# 119  Vrouw  03/97  3   ...      4   3  43       158           34
#
#      AQsocialSkill  AQattSwitch  AQcomm  AQimagination  AQlevel
# 119             31           28      33             32   highAQ
#
# [1 rows x 67 columns]

# %%
dfacc = dfmerged[['id', 'sex','prem','postm', 'AQlevel']]
dfacc = pd.melt(dfacc, id_vars=['id','sex','AQlevel'], value_vars=['prem','postm'], var_name='prepost', value_name='acc')
dfacc.head()
# Out:
#       id    sex AQlevel prepost       acc
# 0  18019  Vrouw  highAQ    prem  0.203704
# 1  19756  Vrouw  highAQ    prem  0.303571
# 2  20176  Vrouw  highAQ    prem  0.259259
# 3  20179  Vrouw   lowAQ    prem  0.222222
# 4  20191  Vrouw  highAQ    prem  0.115385

# %%
sns.set_context("poster")
sns.violinplot(x="prepost", y="acc", hue="AQlevel", data=dfacc,inner="quartile", split=True);

# %%
model = smf.glm(formula="acc ~ AQlevel*prepost", data=dfacc,  family=sm.families.Binomial())
results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    acc   No. Observations:                  540
# Model:                            GLM   Df Residuals:                      536
# Model Family:                Binomial   Df Model:                            3
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -316.86
# Date:                Sun, 11 Sep 2016   Deviance:                       777.58
# Time:                        02:33:47   Pearson chi2:                     29.4
# No. Iterations:                     7
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.7476      0.186      4.026      0.000         0.384     1.112
# AQlevel[T.lowAQ]                     0.0813      0.263      0.309      0.757        -0.433     0.596
# prepost[T.prem]                     -1.9232      0.276     -6.967      0.000        -2.464    -1.382
# AQlevel[T.lowAQ]:prepost[T.prem]    -0.0209      0.387     -0.054      0.957        -0.780     0.738
# ====================================================================================================

# %%
sns.lmplot(x="AQ", y="diff",hue="sex", data=dfmerged)

#len(dfmerged[dfmerged.sex=='Man'])
sns.jointplot(x="AQlikert", y="diff", data=dfmerged, kind="reg");
sns.axlabel("AQ","difference score")

# %%
sns.residplot(x="AQimagination", y="diff", data=dfmerged, lowess=True, color="g")


#model = sm.OLS(dfmerged['diff'], dfmerged['AQ'])
model = smf.glm(formula="postm ~ AQimagination", data=dfmerged)

results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  postm   No. Observations:                  285
# Model:                            GLM   Df Residuals:                      283
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                 0.0186105493106
# Method:                          IRLS   Log-Likelihood:                 164.33
# Date:                Sun, 11 Sep 2016   Deviance:                       5.2668
# Time:                        02:29:32   Pearson chi2:                     5.27
# No. Iterations:                     4
# =================================================================================
#                     coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         0.8127      0.036     22.627      0.000         0.742     0.883
# AQimagination    -0.0074      0.002     -4.107      0.000        -0.011    -0.004
# =================================================================================

# %%
dfgrid = dfmerged[['sex','prem','postm','diff','AQ','AQlikert', 'AQcomm', 'AQsocialSkill', 'AQattDetail','AQattSwitch','AQimagination']]
g = sns.PairGrid(dfgrid, vars= ['prem','postm','diff','AQ','AQlikert']) # hue= 'sex'
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g = sns.PairGrid(dfgrid, vars= ['prem','postm','diff','AQattSwitch','AQimagination']) # hue= 'sex'
g.map_diag(plt.hist)
g.map_upper(plt.scatter)

# %% [markdown]
# # Study 2: Comparing Mooney performance in participants with ASD and TD controls

# %% [markdown]
# ## Preprocessing mooneyTD
#
# **! Don't run this again, import preprocessed data below**
#
# From raw data to dataframe

# %%
with open('MooneyDataRawASD.csv', 'Ur') as f:
    data = list(list(rec) for rec in csv.reader(f, delimiter='\t'))

expandata=[]

print(len(data))
expandata.append(["id", "trialnb", "blocknb", "prepost", "stim", "response", "rt"])

#print(data[1][2])


for i,row in enumerate(data):
    
    
    if i==0:
        continue
    else:
        trials=row[2].split(']')
        
        
        for trial in trials:
            
            trial = trial.strip('[]')
            if trial=="": continue
            trial = trial.split(',')            
            expandata.append(trial)

print(len(expandata))

with open("datMooneyTD.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(expandata)
# Out:
# 80
# 9481

# %% [markdown]
# ## Read in preprocessed data and run correction key

# %%
df = pd.read_csv("dataMooney-aangepast.csv",)
df.head()
# Out:
#     id  trialnb  blocknb prepost  \
# 0  102        0        0     pre
# 1  102        1        0     pre
# 2  102        2        0     pre
# 3  102        3        0     pre
# 4  102        4        0     pre
#
#                                                 stim response    rt
# 0  http://www.sandervandecruys.be/onlineExp/moone...     hond  5391
# 1  http://www.sandervandecruys.be/onlineExp/moone...      man  7805
# 2  http://www.sandervandecruys.be/onlineExp/moone...    vrouw  7894
# 3  http://www.sandervandecruys.be/onlineExp/moone...     hond  7165
# 4  http://www.sandervandecruys.be/onlineExp/moone...   strand  5215

# %%
def correct(df):


    rk = pd.read_csv("mooneyanswerkey.csv",delimiter='\t')
    acccol = []
    correctRespcol = []
    
    
    for rowNb, row in df.iterrows():


        answer = str(row['response'])
        acc=0
        
        

        if answer!='':
            answer=answer.lower()

            img= row['stim']
            
            
            img=img.split('http://www.sandervandecruys.be/onlineExp/mooneyTD/')
        
            img=img[1].strip('"')
            
            sols= rk.sol[rk['tt'] == img]
            sols=np.array(sols)[0].split(',')
            correctResp=sols

            for i in sols:
                i.strip()
                if fuzz.ratio(i,answer) > 70:
                    acc=1
                    break

        acccol.append(acc)
        correctRespcol.append(correctResp)

    df['acc'] = acccol
    df['correctResp'] = correctRespcol
    #print acccol
    return df

df = correct(df)
df.head()
df.to_csv('dataMooneyTDwithAcc.csv')

# %% [markdown]
# ## Import & check data

# %%
df= pd.read_csv('dataMooneyTDwithAcc.csv')

df.head()
# Out:
#    Unnamed: 0   id  trialnb  blocknb prepost  \
# 0           0  102        0        0     pre
# 1           1  102        1        0     pre
# 2           2  102        2        0     pre
# 3           3  102        3        0     pre
# 4           4  102        4        0     pre
#
#                                                 stim response    rt  acc  \
# 0  http://www.sandervandecruys.be/onlineExp/moone...     hond  5391    0
# 1  http://www.sandervandecruys.be/onlineExp/moone...      man  7805    0
# 2  http://www.sandervandecruys.be/onlineExp/moone...    vrouw  7894    0
# 3  http://www.sandervandecruys.be/onlineExp/moone...     hond  7165    0
# 4  http://www.sandervandecruys.be/onlineExp/moone...   strand  5215    0
#
#                                          correctResp
# 0               ['kikker', ' pad', ' toad', ' frog']
# 1  ['hagedis', ' kameleon', ' leguaan', ' lizard'...
# 2                 ['uil', ' owl', ' vogel', ' bird']
# 3  ['luipaard', ' jachtluipaard', ' jaguar', ' le...
# 4                         ['kangoeroe', ' kangaroo']

# %% [markdown]
# ## Merge descriptive data with experimental data

# %%
dfDescriptive = pd.read_excel("DescriptiveData.xls")

#df.id = df["id"].str.strip("\"")
#df.id = df["id"].astype(int)

dfmerged= pd.merge(df, dfDescriptive, on='id')

print(len(dfmerged['id'].unique()))
print(len(dfmerged))


dfmerged.to_csv('dataMooneywithDescriptive.csv')

df= dfmerged


df.head()
# Out:
# 49
# 5880
#    Unnamed: 0   id  trialnb  blocknb prepost  \
# 0           0  102        0        0     pre
# 1           1  102        1        0     pre
# 2           2  102        2        0     pre
# 3           3  102        3        0     pre
# 4           4  102        4        0     pre
#
#                                                 stim response    rt  acc  \
# 0  http://www.sandervandecruys.be/onlineExp/moone...     hond  5391    0
# 1  http://www.sandervandecruys.be/onlineExp/moone...      man  7805    0
# 2  http://www.sandervandecruys.be/onlineExp/moone...    vrouw  7894    0
# 3  http://www.sandervandecruys.be/onlineExp/moone...     hond  7165    0
# 4  http://www.sandervandecruys.be/onlineExp/moone...   strand  5215    0
#
#                                          correctResp          ...           \
# 0               ['kikker', ' pad', ' toad', ' frog']          ...
# 1  ['hagedis', ' kameleon', ' leguaan', ' lizard'...          ...
# 2                 ['uil', ' owl', ' vogel', ' bird']          ...
# 3  ['luipaard', ' jachtluipaard', ' jaguar', ' le...          ...
# 4                         ['kangoeroe', ' kangaroo']          ...
#
#    TIQ  VIQ  PIQ SRS_overall SRS_consciousness  SRS_Cognition  \
# 0  107   97  117          37                37             41
# 1  107   97  117          37                37             41
# 2  107   97  117          37                37             41
# 3  107   97  117          37                37             41
# 4  107   97  117          37                37             41
#
#    SRS_Communication  SRS_Motivation  SRS_Preoccupation  ADOS: Above cut-off?
# 0                 37              38                 45                   NaN
# 1                 37              38                 45                   NaN
# 2                 37              38                 45                   NaN
# 3                 37              38                 45                   NaN
# 4                 37              38                 45                   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Explore data: should we exclude people?

# %%
for i, v in enumerate(df.columns):
    print(i, v)
print(df.dtypes)
# Out:
# 0 Unnamed: 0
# 1 id
# 2 trialnb
# 3 blocknb
# 4 prepost
# 5 stim
# 6 response
# 7 rt
# 8 acc
# 9 correctResp
# 10 Initials
# 11 Age
# 12 Gender
# 13 Handedness
# 14 Group
# 15 TIQ
# 16 VIQ
# 17 PIQ
# 18 SRS_overall
# 19 SRS_consciousness
# 20 SRS_Cognition
# 21 SRS_Communication
# 22 SRS_Motivation
# 23 SRS_Preoccupation
# 24 ADOS: Above cut-off?
# Unnamed: 0                int64
# id                        int64
# trialnb                   int64
# blocknb                   int64
# prepost                  object
# stim                     object
# response                 object
# rt                      float64
# acc                       int64
# correctResp              object
# Initials                 object
# Age                       int64
# Gender                   object
# Handedness               object
# Group                    object
# TIQ                     float64
# VIQ                       int64
# PIQ                       int64
# SRS_overall               int64
# SRS_consciousness         int64
# SRS_Cognition             int64
# SRS_Communication         int64
# SRS_Motivation            int64
# SRS_Preoccupation         int64
# ADOS: Above cut-off?     object
# dtype: object

# %%
sns.pointplot(x="prepost", y="acc",units="id",data=df);

# %%
idmeans= df.groupby('id').acc.mean()
idmeans[idmeans<.2]
# Out:
# id
# 204    0.108333
# 229    0.100000
# Name: acc, dtype: float64

# %% [markdown]
# **Participant 204 and 229 did not reach .2 accuracy and will be excluded from the rest of the analyses**

# %%
df= df.loc[df.id!=204]
df= df.loc[df.id!=229]

# %%
sns.factorplot(x="id", y="acc", data=df, size=6, kind="bar", palette="muted")

# %% [markdown]
# ## Does performance (pre, post acc) depend on group or block?

# %%
sns.factorplot(x="blocknb", y="acc",hue='Group', col='prepost', units="id",data=df);
#sns.pointplot(x="blocknb", y="acc",hue="prepost", units="id",data=df[df.Group=='TD']);

# %%
model = smf.glm(formula="acc ~ Group*prepost*blocknb", data=df,  family=sm.families.Binomial())
results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    acc   No. Observations:                 5640
# Model:                            GLM   Df Residuals:                     5632
# Model Family:                Binomial   Df Model:                            7
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -3225.2
# Date:                Sat, 10 Sep 2016   Deviance:                       6450.5
# Time:                        02:07:47   Pearson chi2:                 5.64e+03
# No. Iterations:                     6
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.8311      0.106      7.806      0.000         0.622     1.040
# Group[T.TD]                           -0.0318      0.148     -0.214      0.830        -0.323     0.259
# prepost[T.pre]                        -2.1676      0.156    -13.933      0.000        -2.473    -1.863
# Group[T.TD]:prepost[T.pre]             0.1000      0.217      0.462      0.644        -0.324     0.524
# blocknb                                0.1241      0.037      3.345      0.001         0.051     0.197
# Group[T.TD]:blocknb                   -0.0030      0.052     -0.059      0.953        -0.104     0.098
# prepost[T.pre]:blocknb                 0.0250      0.051      0.486      0.627        -0.076     0.126
# Group[T.TD]:prepost[T.pre]:blocknb    -0.0169      0.072     -0.235      0.814        -0.157     0.124
# ======================================================================================================

# %%
# model formulation
fml = "acc ~ prepost * Group + SRS_overall + PIQ"


# covariance structure
ex = sm.cov_struct.Exchangeable()
#link fu
fa = sm.families.Binomial(sm.families.links.logit)

model = sm.GEE.from_formula(fml, "id", df, cov_struct=ex, family=fa)
result = model.fit()



print(result.summary())
print(result.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                         acc   No. Observations:                 5640
# Model:                                 GEE   No. clusters:                       47
# Method:                        Generalized   Min. cluster size:                 120
#                       Estimating Equations   Max. cluster size:                 120
# Family:                           Binomial   Mean cluster size:               120.0
# Dependence structure:         Exchangeable   Num. iterations:                    12
# Date:                     Sat, 10 Sep 2016   Scale:                           1.002
# Covariance type:                    robust   Time:                         02:08:06
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.4924      0.750     -0.657      0.511        -1.962     0.977
# prepost[T.pre]                -2.0880      0.103    -20.306      0.000        -2.290    -1.887
# Group[T.TD]                    0.0957      0.242      0.395      0.693        -0.379     0.570
# prepost[T.pre]:Group[T.TD]     0.0490      0.153      0.320      0.749        -0.251     0.349
# SRS_overall                    0.0043      0.006      0.739      0.460        -0.007     0.016
# PIQ                            0.0119      0.005      2.407      0.016         0.002     0.022
# ==============================================================================
# Skew:                         -0.0299   Kurtosis:                      -0.8447
# Centered skew:                -0.0251   Centered kurtosis:             -0.7854
# ==============================================================================
# The correlation between two observations in the same cluster is 0.033

# %%
# odds ratio: 
# http://stats.stackexchange.com/questions/133623/help-me-understand-adjusted-odds-ratio-in-logistic-regression
oddsratio = 1- (1/(1+np.exp(-2.088)))
oddsratio
# Out:
# 0.11026864040567408

# %% [markdown]
# ## Interim conclusion
#
# * There is a clear effect of the exposure to the "templates".
# * There is also a clear learning effect (blocknb)
# * There is no significant group effect or group*phase interaction.
# * These conclusions hold also when correcting for IQ (matched) and SRS scores. IQ (specifically PIQ) seems to modulate the effect (see below).
# * The use of prior (top-down) information is not reduced or increased in ASD.

# %% [markdown]
# ## Compute diff scores (postmean minus premean)

# %%
print(len(df['id'].unique()))


def diffScore(df):
    
    after = df[df.prepost=='post'].acc.mean()
    before = df[df.prepost=='pre'].acc.mean()
    countsPre= df[df.prepost=='pre'].response.count()
    countsPost= df[df.prepost=='post'].response.count()
    fa= (df[df.prepost=='pre'].acc.sum())/float(countsPre)
    
    diff= after - before 
    
    SRS_overall = df.SRS_overall.mean()
    PIQ = df.PIQ.mean()
    TIQ = df.TIQ.mean()    
    group = df['Group'].iloc[0]
    
    
    #df['id'].iloc[0]
    dfout = pd.DataFrame(data=[(group, PIQ, TIQ, SRS_overall, before, after, diff, countsPre, countsPost, fa)], \
                         columns=['group','PIQ', 'TIQ','SRS_overall','before', 'after', 'diff', \
                                  'countsPre', 'countsPost', 'fa'])
    
    return dfout

dfdiff = df.groupby('id').apply(diffScore)

dfdiff = dfdiff.reset_index()

dfdiff.head()
# Out:
# 47
#     id  level_1 group  PIQ    TIQ  SRS_overall    before     after      diff  \
# 0  102        0    TD  117  107.0           37  0.283333  0.750000  0.466667
# 1  103        0    TD  114  111.5           48  0.200000  0.466667  0.266667
# 2  104        0    TD  123  115.5           56  0.400000  0.900000  0.500000
# 3  105        0    TD  103  107.0           45  0.116667  0.650000  0.533333
# 4  106        0    TD  100  101.5           49  0.233333  0.866667  0.633333
#
#    countsPre  countsPost        fa
# 0         60          60  0.283333
# 1         60          60  0.200000
# 2         49          58  0.489796
# 3         52          59  0.134615
# 4         58          60  0.241379

# %% [markdown]
# ## Statistical test on the diff scores and on counts

# %%
# GLM test

model = smf.glm(formula="diff ~ group * SRS_overall * PIQ", data=dfdiff)

results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   diff   No. Observations:                   47
# Model:                            GLM   Df Residuals:                       39
# Model Family:                Gaussian   Df Model:                            7
# Link Function:               identity   Scale:                0.00966927690589
# Method:                          IRLS   Log-Likelihood:                 46.707
# Date:                Sat, 10 Sep 2016   Deviance:                      0.37710
# Time:                        02:09:37   Pearson chi2:                    0.377
# No. Iterations:                     4
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.2147      1.795     -0.120      0.905        -3.733     3.304
# group[T.TD]                     1.5695      2.179      0.720      0.471        -2.700     5.839
# SRS_overall                     0.0111      0.022      0.503      0.615        -0.032     0.054
# group[T.TD]:SRS_overall        -0.0376      0.033     -1.127      0.260        -0.103     0.028
# PIQ                             0.0061      0.016      0.373      0.709        -0.026     0.038
# group[T.TD]:PIQ                -0.0134      0.020     -0.666      0.505        -0.053     0.026
# SRS_overall:PIQ              -9.82e-05      0.000     -0.493      0.622        -0.000     0.000
# group[T.TD]:SRS_overall:PIQ     0.0003      0.000      1.049      0.294        -0.000     0.001
# ===============================================================================================

# %%
# GLM test of counts

model = smf.glm(formula="countsPre ~ group * SRS_overall * PIQ", data=dfdiff)

results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              countsPre   No. Observations:                   47
# Model:                            GLM   Df Residuals:                       39
# Model Family:                Gaussian   Df Model:                            7
# Link Function:               identity   Scale:                   178.752309283
# Method:                          IRLS   Log-Likelihood:                -184.18
# Date:                Sat, 10 Sep 2016   Deviance:                       6971.3
# Time:                        02:11:59   Pearson chi2:                 6.97e+03
# No. Iterations:                     4
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                    -249.4742    244.086     -1.022      0.307      -727.874   228.926
# group[T.TD]                   196.8514    296.203      0.665      0.506      -383.696   777.399
# SRS_overall                     3.2852      2.989      1.099      0.272        -2.572     9.143
# group[T.TD]:SRS_overall        -1.3675      4.538     -0.301      0.763       -10.261     7.526
# PIQ                             2.5301      2.211      1.144      0.252        -1.803     6.863
# group[T.TD]:PIQ                -1.6698      2.727     -0.612      0.540        -7.014     3.674
# SRS_overall:PIQ                -0.0276      0.027     -1.020      0.308        -0.081     0.025
# group[T.TD]:SRS_overall:PIQ     0.0120      0.042      0.283      0.777        -0.071     0.095
# ===============================================================================================

# %% [markdown]
# ## Make violin plots for inspecting differences and distributions

# %%
# reshape data

#dfdiff = dfdiff[dfdiff.postm>.2]
dfmelted = pd.melt(dfdiff, id_vars=['id','group'], value_vars=['before', 'after'], var_name=["prepost"], value_name='acc')
dfmelted.head()
# Out:
#     id group prepost       acc
# 0  102    TD  before  0.283333
# 1  103    TD  before  0.200000
# 2  104    TD  before  0.400000
# 3  105    TD  before  0.116667
# 4  106    TD  before  0.233333

# %%
sns.set_context("poster")
#sns.swarmplot(x="prepost", y="acc", hue="group", data=dfmelted, palette="dark")
sns.violinplot(x="prepost", y="acc", hue="group", data=dfmelted, split=True, inner="stick");
sns.axlabel("Phase", "Mean accuracy")
sns.despine(left=True)

# %% [markdown]
# ## Check correlations with SRS

# %%
sns.jointplot(x="SRS_overall", y="diff", data=dfdiff[dfdiff.group=='TD'], kind="reg");
sns.lmplot(x="SRS_overall", y="diff", hue='group', data=dfdiff);

# %%
sns.jointplot(x="SRS_overall", y="countsPre", data=dfdiff[dfdiff.group=='TD'], kind="reg");
sns.lmplot(x="SRS_overall", y="countsPre", hue='group', data=dfdiff);

# %% [markdown]
# ## Interim conclusion
#
# * No notable correlations between SRS_overall & diff, premean, counts

# %% [markdown]
# ## Check correlations with IQ

# %%
sns.jointplot(x="PIQ", y="diff", data=dfdiff[dfdiff.group=='TD'], kind="reg");
sns.lmplot(x="PIQ", y="diff", hue='group', data=dfdiff);

# %%
sns.jointplot(x="PIQ", y="countsPre", data=dfdiff[dfdiff.group=='ASD'], kind="reg");
sns.lmplot(x="PIQ", y="countsPost", hue='group', data=dfdiff);

# %% [markdown]
# ## Interim conclusion
#
# * No notable correlations with IQ in premean or counts
# * There might be a positive correlation between diff (not in before acc) and PIQ, but not in ASD group (or not enough spread in PIQ). This will likely not survive multiple comparison correction.

# %% [markdown]
# # TODO
#
# *
